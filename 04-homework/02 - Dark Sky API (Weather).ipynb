# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
from dotenv import load_dotenv
load_dotenv()
import os

API_KEY = os.getenv("dark_sky_api_key")

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url = 'https://api.darksky.net/forecast/50614b874393730eb3ea9d826fcd6278/40.73,-74.08'

# %%
response = requests.get(url)
JC = response.json()

# %%
JC
# Out:
# {'latitude': 40.73,
#  'longitude': -74.08,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560027777,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'nearestStormDistance': 24,
#   'nearestStormBearing': 176,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 78.98,
#   'apparentTemperature': 78.98,
#   'dewPoint': 48.38,
#   'humidity': 0.34,
#   'pressure': 1021.7,
#   'windSpeed': 8.96,
#   'windGust': 9.69,
#   'windBearing': 134,
#   'cloudCover': 0.05,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 336.12},
#  'minutely': {'summary': 'Clear for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560027720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560027780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560027840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560027900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560027960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560028980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560029940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560030960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560031320, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Partly cloudy starting later this evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560027600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.06,
#     'apparentTemperature': 79.06,
#     'dewPoint': 48.4,
#     'humidity': 0.34,
#     'pressure': 1021.69,
#     'windSpeed': 8.98,
#     'windGust': 9.71,
#     'windBearing': 134,
#     'cloudCover': 0.05,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 336.11},
#    {'time': 1560031200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.4,
#     'apparentTemperature': 77.4,
#     'dewPoint': 48.05,
#     'humidity': 0.36,
#     'pressure': 1021.84,
#     'windSpeed': 8.75,
#     'windGust': 9.47,
#     'windBearing': 133,
#     'cloudCover': 0.05,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 336.25},
#    {'time': 1560034800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 75.5,
#     'apparentTemperature': 75.5,
#     'dewPoint': 48.26,
#     'humidity': 0.38,
#     'pressure': 1022.16,
#     'windSpeed': 8.87,
#     'windGust': 12.64,
#     'windBearing': 128,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.05},
#    {'time': 1560038400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.9,
#     'apparentTemperature': 72.9,
#     'dewPoint': 48.3,
#     'humidity': 0.42,
#     'pressure': 1022.68,
#     'windSpeed': 8.17,
#     'windGust': 16.46,
#     'windBearing': 124,
#     'cloudCover': 0.49,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.92},
#    {'time': 1560042000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 70.02,
#     'apparentTemperature': 70.02,
#     'dewPoint': 49.31,
#     'humidity': 0.48,
#     'pressure': 1023.07,
#     'windSpeed': 6.86,
#     'windGust': 17.98,
#     'windBearing': 107,
#     'cloudCover': 0.69,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.9},
#    {'time': 1560045600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 67.87,
#     'apparentTemperature': 67.87,
#     'dewPoint': 49.79,
#     'humidity': 0.52,
#     'pressure': 1023.57,
#     'windSpeed': 6.77,
#     'windGust': 16.76,
#     'windBearing': 96,
#     'cloudCover': 0.69,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.9},
#    {'time': 1560049200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 66.51,
#     'apparentTemperature': 66.51,
#     'dewPoint': 50.21,
#     'humidity': 0.56,
#     'pressure': 1023.84,
#     'windSpeed': 6.1,
#     'windGust': 14.16,
#     'windBearing': 88,
#     'cloudCover': 0.5,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.84},
#    {'time': 1560052800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 65.62,
#     'apparentTemperature': 65.62,
#     'dewPoint': 50.3,
#     'humidity': 0.58,
#     'pressure': 1024.24,
#     'windSpeed': 5.72,
#     'windGust': 12.45,
#     'windBearing': 74,
#     'cloudCover': 0.49,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.59},
#    {'time': 1560056400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.89,
#     'apparentTemperature': 64.89,
#     'dewPoint': 50.39,
#     'humidity': 0.59,
#     'pressure': 1024.36,
#     'windSpeed': 5.9,
#     'windGust': 12.49,
#     'windBearing': 72,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.29},
#    {'time': 1560060000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.08,
#     'apparentTemperature': 64.08,
#     'dewPoint': 50.53,
#     'humidity': 0.61,
#     'pressure': 1024.47,
#     'windSpeed': 5.49,
#     'windGust': 12.34,
#     'windBearing': 64,
#     'cloudCover': 0.29,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335},
#    {'time': 1560063600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.31,
#     'apparentTemperature': 63.31,
#     'dewPoint': 50.4,
#     'humidity': 0.63,
#     'pressure': 1024.73,
#     'windSpeed': 6.02,
#     'windGust': 12.74,
#     'windBearing': 61,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.69},
#    {'time': 1560067200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.25,
#     'apparentTemperature': 62.25,
#     'dewPoint': 50.22,
#     'humidity': 0.65,
#     'pressure': 1024.95,
#     'windSpeed': 6.12,
#     'windGust': 12.74,
#     'windBearing': 58,
#     'cloudCover': 0.46,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.37},
#    {'time': 1560070800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 61.29,
#     'apparentTemperature': 61.29,
#     'dewPoint': 50.08,
#     'humidity': 0.67,
#     'pressure': 1025.16,
#     'windSpeed': 6.43,
#     'windGust': 13.14,
#     'windBearing': 56,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.15},
#    {'time': 1560074400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.52,
#     'apparentTemperature': 61.52,
#     'dewPoint': 50.15,
#     'humidity': 0.66,
#     'pressure': 1025.45,
#     'windSpeed': 6.7,
#     'windGust': 13.79,
#     'windBearing': 57,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.1},
#    {'time': 1560078000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.73,
#     'apparentTemperature': 64.73,
#     'dewPoint': 49.76,
#     'humidity': 0.58,
#     'pressure': 1026,
#     'windSpeed': 7.78,
#     'windGust': 15.45,
#     'windBearing': 65,
#     'cloudCover': 0.74,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.14},
#    {'time': 1560081600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.2,
#     'apparentTemperature': 66.2,
#     'dewPoint': 49.34,
#     'humidity': 0.55,
#     'pressure': 1026.24,
#     'windSpeed': 8.39,
#     'windGust': 16.92,
#     'windBearing': 70,
#     'cloudCover': 0.72,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 333.93},
#    {'time': 1560085200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69,
#     'apparentTemperature': 69,
#     'dewPoint': 48.2,
#     'humidity': 0.48,
#     'pressure': 1026.56,
#     'windSpeed': 9.29,
#     'windGust': 17.9,
#     'windBearing': 81,
#     'cloudCover': 0.69,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 333.06},
#    {'time': 1560088800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.45,
#     'apparentTemperature': 72.45,
#     'dewPoint': 46.78,
#     'humidity': 0.4,
#     'pressure': 1026.87,
#     'windSpeed': 10.31,
#     'windGust': 18.61,
#     'windBearing': 94,
#     'cloudCover': 0.65,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 331.87},
#    {'time': 1560092400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.15,
#     'apparentTemperature': 75.15,
#     'dewPoint': 45.72,
#     'humidity': 0.35,
#     'pressure': 1027.03,
#     'windSpeed': 11.24,
#     'windGust': 19.09,
#     'windBearing': 104,
#     'cloudCover': 0.61,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 331.12},
#    {'time': 1560096000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.87,
#     'apparentTemperature': 76.87,
#     'dewPoint': 45.35,
#     'humidity': 0.33,
#     'pressure': 1027.02,
#     'windSpeed': 12.12,
#     'windGust': 19.41,
#     'windBearing': 111,
#     'cloudCover': 0.56,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 331.21},
#    {'time': 1560099600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.65,
#     'apparentTemperature': 77.65,
#     'dewPoint': 45.34,
#     'humidity': 0.32,
#     'pressure': 1026.84,
#     'windSpeed': 12.93,
#     'windGust': 19.64,
#     'windBearing': 115,
#     'cloudCover': 0.51,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 331.77},
#    {'time': 1560103200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.2,
#     'apparentTemperature': 78.2,
#     'dewPoint': 45.25,
#     'humidity': 0.31,
#     'pressure': 1026.68,
#     'windSpeed': 13.4,
#     'windGust': 19.7,
#     'windBearing': 118,
#     'cloudCover': 0.48,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 331.98},
#    {'time': 1560106800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.99,
#     'apparentTemperature': 77.99,
#     'dewPoint': 44.82,
#     'humidity': 0.31,
#     'pressure': 1026.53,
#     'windSpeed': 13.3,
#     'windGust': 19.46,
#     'windBearing': 119,
#     'cloudCover': 0.47,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 331.61},
#    {'time': 1560110400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.23,
#     'apparentTemperature': 77.23,
#     'dewPoint': 44.29,
#     'humidity': 0.31,
#     'pressure': 1026.38,
#     'windSpeed': 12.86,
#     'windGust': 19.01,
#     'windBearing': 119,
#     'cloudCover': 0.46,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 330.99},
#    {'time': 1560114000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.16,
#     'apparentTemperature': 76.16,
#     'dewPoint': 43.94,
#     'humidity': 0.32,
#     'pressure': 1026.23,
#     'windSpeed': 12.32,
#     'windGust': 18.55,
#     'windBearing': 117,
#     'cloudCover': 0.45,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 330.4},
#    {'time': 1560117600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.7,
#     'apparentTemperature': 74.7,
#     'dewPoint': 43.81,
#     'humidity': 0.33,
#     'pressure': 1026.13,
#     'windSpeed': 11.66,
#     'windGust': 17.94,
#     'windBearing': 116,
#     'cloudCover': 0.4,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 330.02},
#    {'time': 1560121200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.78,
#     'apparentTemperature': 72.78,
#     'dewPoint': 43.83,
#     'humidity': 0.35,
#     'pressure': 1026.07,
#     'windSpeed': 10.92,
#     'windGust': 17.2,
#     'windBearing': 113,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.68},
#    {'time': 1560124800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.86,
#     'apparentTemperature': 70.86,
#     'dewPoint': 44.13,
#     'humidity': 0.38,
#     'pressure': 1025.97,
#     'windSpeed': 10.21,
#     'windGust': 16.67,
#     'windBearing': 110,
#     'cloudCover': 0.34,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.29},
#    {'time': 1560128400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.1,
#     'apparentTemperature': 69.1,
#     'dewPoint': 44.98,
#     'humidity': 0.42,
#     'pressure': 1025.93,
#     'windSpeed': 9.59,
#     'windGust': 16.61,
#     'windBearing': 106,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.96},
#    {'time': 1560132000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.33,
#     'apparentTemperature': 67.33,
#     'dewPoint': 46.23,
#     'humidity': 0.47,
#     'pressure': 1025.87,
#     'windSpeed': 9,
#     'windGust': 16.85,
#     'windBearing': 101,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.5},
#    {'time': 1560135600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.96,
#     'apparentTemperature': 65.96,
#     'dewPoint': 47.48,
#     'humidity': 0.51,
#     'pressure': 1025.73,
#     'windSpeed': 8.47,
#     'windGust': 16.89,
#     'windBearing': 96,
#     'cloudCover': 0.66,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.89},
#    {'time': 1560139200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.16,
#     'apparentTemperature': 65.16,
#     'dewPoint': 48.57,
#     'humidity': 0.55,
#     'pressure': 1025.43,
#     'windSpeed': 8.07,
#     'windGust': 16.53,
#     'windBearing': 92,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 326.89},
#    {'time': 1560142800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.49,
#     'apparentTemperature': 64.49,
#     'dewPoint': 49.66,
#     'humidity': 0.59,
#     'pressure': 1025.04,
#     'windSpeed': 7.76,
#     'windGust': 15.98,
#     'windBearing': 89,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 325.66},
#    {'time': 1560146400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.91,
#     'apparentTemperature': 63.91,
#     'dewPoint': 50.67,
#     'humidity': 0.62,
#     'pressure': 1024.52,
#     'windSpeed': 7.58,
#     'windGust': 15.61,
#     'windBearing': 85,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.67},
#    {'time': 1560150000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.9,
#     'apparentTemperature': 62.9,
#     'dewPoint': 51.57,
#     'humidity': 0.67,
#     'pressure': 1023.88,
#     'windSpeed': 7.6,
#     'windGust': 15.55,
#     'windBearing': 82,
#     'cloudCover': 0.49,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.06},
#    {'time': 1560153600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 62.14,
#     'apparentTemperature': 62.14,
#     'dewPoint': 52.4,
#     'humidity': 0.7,
#     'pressure': 1023.15,
#     'windSpeed': 7.73,
#     'windGust': 15.64,
#     'windBearing': 79,
#     'cloudCover': 0.7,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.66},
#    {'time': 1560157200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0009,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 61.46,
#     'apparentTemperature': 61.46,
#     'dewPoint': 53.3,
#     'humidity': 0.75,
#     'pressure': 1022.53,
#     'windSpeed': 7.85,
#     'windGust': 15.88,
#     'windBearing': 77,
#     'cloudCover': 0.86,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.22},
#    {'time': 1560160800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 61.64,
#     'apparentTemperature': 61.64,
#     'dewPoint': 54.3,
#     'humidity': 0.77,
#     'pressure': 1022.16,
#     'windSpeed': 7.95,
#     'windGust': 16.3,
#     'windBearing': 77,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.7},
#    {'time': 1560164400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.005,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 61.99,
#     'apparentTemperature': 61.99,
#     'dewPoint': 55.37,
#     'humidity': 0.79,
#     'pressure': 1021.93,
#     'windSpeed': 8.03,
#     'windGust': 16.88,
#     'windBearing': 78,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.11},
#    {'time': 1560168000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0079,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 62.74,
#     'apparentTemperature': 62.74,
#     'dewPoint': 56.54,
#     'humidity': 0.8,
#     'pressure': 1021.6,
#     'windSpeed': 8.2,
#     'windGust': 17.46,
#     'windBearing': 80,
#     'cloudCover': 0.89,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 321.71},
#    {'time': 1560171600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0093,
#     'precipProbability': 0.22,
#     'precipType': 'rain',
#     'temperature': 63.66,
#     'apparentTemperature': 63.66,
#     'dewPoint': 57.86,
#     'humidity': 0.81,
#     'pressure': 1021.19,
#     'windSpeed': 8.49,
#     'windGust': 17.86,
#     'windBearing': 84,
#     'cloudCover': 0.93,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 321.42},
#    {'time': 1560175200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0103,
#     'precipProbability': 0.23,
#     'precipType': 'rain',
#     'temperature': 64.91,
#     'apparentTemperature': 64.96,
#     'dewPoint': 59.29,
#     'humidity': 0.82,
#     'pressure': 1020.69,
#     'windSpeed': 8.85,
#     'windGust': 18.29,
#     'windBearing': 89,
#     'cloudCover': 0.97,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 321.27},
#    {'time': 1560178800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0118,
#     'precipProbability': 0.29,
#     'precipType': 'rain',
#     'temperature': 65.91,
#     'apparentTemperature': 66.11,
#     'dewPoint': 60.6,
#     'humidity': 0.83,
#     'pressure': 1020.11,
#     'windSpeed': 9.29,
#     'windGust': 18.99,
#     'windBearing': 94,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 321.12},
#    {'time': 1560182400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0194,
#     'precipProbability': 0.36,
#     'precipType': 'rain',
#     'temperature': 66.3,
#     'apparentTemperature': 66.64,
#     'dewPoint': 61.76,
#     'humidity': 0.85,
#     'pressure': 1019.39,
#     'windSpeed': 9.92,
#     'windGust': 20.36,
#     'windBearing': 98,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 9.89,
#     'ozone': 321.05},
#    {'time': 1560186000,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0393,
#     'precipProbability': 0.47,
#     'precipType': 'rain',
#     'temperature': 67.42,
#     'apparentTemperature': 67.87,
#     'dewPoint': 62.83,
#     'humidity': 0.85,
#     'pressure': 1018.58,
#     'windSpeed': 10.65,
#     'windGust': 21.94,
#     'windBearing': 101,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 9.83,
#     'ozone': 321.01},
#    {'time': 1560189600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0575,
#     'precipProbability': 0.58,
#     'precipType': 'rain',
#     'temperature': 68.37,
#     'apparentTemperature': 68.9,
#     'dewPoint': 63.65,
#     'humidity': 0.85,
#     'pressure': 1017.73,
#     'windSpeed': 11.1,
#     'windGust': 22.88,
#     'windBearing': 104,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 9.84,
#     'ozone': 320.82},
#    {'time': 1560193200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.056,
#     'precipProbability': 0.63,
#     'precipType': 'rain',
#     'temperature': 68.9,
#     'apparentTemperature': 69.47,
#     'dewPoint': 64.09,
#     'humidity': 0.85,
#     'pressure': 1016.8,
#     'windSpeed': 11.17,
#     'windGust': 22.8,
#     'windBearing': 108,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 9.71,
#     'ozone': 320.4},
#    {'time': 1560196800,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0451,
#     'precipProbability': 0.61,
#     'precipType': 'rain',
#     'temperature': 68.78,
#     'apparentTemperature': 69.39,
#     'dewPoint': 64.33,
#     'humidity': 0.86,
#     'pressure': 1015.83,
#     'windSpeed': 11.02,
#     'windGust': 22.06,
#     'windBearing': 112,
#     'cloudCover': 1,
#     'uvIndex': 3,
#     'visibility': 9.48,
#     'ozone': 319.7},
#    {'time': 1560200400,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0341,
#     'precipProbability': 0.56,
#     'precipType': 'rain',
#     'temperature': 68.64,
#     'apparentTemperature': 69.28,
#     'dewPoint': 64.56,
#     'humidity': 0.87,
#     'pressure': 1014.94,
#     'windSpeed': 10.78,
#     'windGust': 20.96,
#     'windBearing': 115,
#     'cloudCover': 1,
#     'uvIndex': 2,
#     'visibility': 9.41,
#     'ozone': 319.17}]},
#  'daily': {'summary': 'Rain on Monday through Thursday, with high temperatures bottoming out at 66°F on Thursday.',
#   'icon': 'rain',
#   'data': [{'time': 1559966400,
#     'summary': 'Partly cloudy starting in the evening.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1559985995,
#     'sunsetTime': 1560040027,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0015,
#     'precipIntensityMaxTime': 1560042000,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 81.21,
#     'temperatureHighTime': 1560016800,
#     'temperatureLow': 61.29,
#     'temperatureLowTime': 1560070800,
#     'apparentTemperatureHigh': 81.21,
#     'apparentTemperatureHighTime': 1560016800,
#     'apparentTemperatureLow': 61.29,
#     'apparentTemperatureLowTime': 1560070800,
#     'dewPoint': 52.96,
#     'humidity': 0.56,
#     'pressure': 1019.99,
#     'windSpeed': 4.7,
#     'windGust': 17.98,
#     'windGustTime': 1560042000,
#     'windBearing': 98,
#     'cloudCover': 0.21,
#     'uvIndex': 8,
#     'uvIndexTime': 1560009600,
#     'visibility': 9.62,
#     'ozone': 330.08,
#     'temperatureMin': 62.95,
#     'temperatureMinTime': 1559977200,
#     'temperatureMax': 81.21,
#     'temperatureMaxTime': 1560016800,
#     'apparentTemperatureMin': 63.24,
#     'apparentTemperatureMinTime': 1559977200,
#     'apparentTemperatureMax': 81.21,
#     'apparentTemperatureMaxTime': 1560016800},
#    {'time': 1560052800,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560072383,
#     'sunsetTime': 1560126461,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0016,
#     'precipIntensityMaxTime': 1560070800,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 78.2,
#     'temperatureHighTime': 1560103200,
#     'temperatureLow': 61.46,
#     'temperatureLowTime': 1560157200,
#     'apparentTemperatureHigh': 78.2,
#     'apparentTemperatureHighTime': 1560103200,
#     'apparentTemperatureLow': 61.46,
#     'apparentTemperatureLowTime': 1560157200,
#     'dewPoint': 47.14,
#     'humidity': 0.46,
#     'pressure': 1025.89,
#     'windSpeed': 8.76,
#     'windGust': 19.7,
#     'windGustTime': 1560103200,
#     'windBearing': 98,
#     'cloudCover': 0.52,
#     'uvIndex': 7,
#     'uvIndexTime': 1560099600,
#     'visibility': 10,
#     'ozone': 332.07,
#     'temperatureMin': 61.29,
#     'temperatureMinTime': 1560070800,
#     'temperatureMax': 78.2,
#     'temperatureMaxTime': 1560103200,
#     'apparentTemperatureMin': 61.29,
#     'apparentTemperatureMinTime': 1560070800,
#     'apparentTemperatureMax': 78.2,
#     'apparentTemperatureMaxTime': 1560103200},
#    {'time': 1560139200,
#     'summary': 'Rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560158773,
#     'sunsetTime': 1560212894,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0165,
#     'precipIntensityMax': 0.0575,
#     'precipIntensityMaxTime': 1560189600,
#     'precipProbability': 0.98,
#     'precipType': 'rain',
#     'temperatureHigh': 68.9,
#     'temperatureHighTime': 1560193200,
#     'temperatureLow': 68.3,
#     'temperatureLowTime': 1560211200,
#     'apparentTemperatureHigh': 69.47,
#     'apparentTemperatureHighTime': 1560193200,
#     'apparentTemperatureLow': 69.09,
#     'apparentTemperatureLowTime': 1560211200,
#     'dewPoint': 59.38,
#     'humidity': 0.8,
#     'pressure': 1018.83,
#     'windSpeed': 8.69,
#     'windGust': 22.88,
#     'windGustTime': 1560189600,
#     'windBearing': 100,
#     'cloudCover': 0.87,
#     'uvIndex': 4,
#     'uvIndexTime': 1560178800,
#     'visibility': 9.7,
#     'ozone': 321.56,
#     'temperatureMin': 61.46,
#     'temperatureMinTime': 1560157200,
#     'temperatureMax': 68.97,
#     'temperatureMaxTime': 1560222000,
#     'apparentTemperatureMin': 61.46,
#     'apparentTemperatureMinTime': 1560157200,
#     'apparentTemperatureMax': 69.87,
#     'apparentTemperatureMaxTime': 1560222000},
#    {'time': 1560225600,
#     'summary': 'Rain in the morning and breezy in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560245166,
#     'sunsetTime': 1560299324,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.019,
#     'precipIntensityMax': 0.0622,
#     'precipIntensityMaxTime': 1560243600,
#     'precipProbability': 0.91,
#     'precipType': 'rain',
#     'temperatureHigh': 79.5,
#     'temperatureHighTime': 1560283200,
#     'temperatureLow': 59.28,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 79.5,
#     'apparentTemperatureHighTime': 1560283200,
#     'apparentTemperatureLow': 59.28,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 55.11,
#     'humidity': 0.6,
#     'pressure': 1011.22,
#     'windSpeed': 7.3,
#     'windGust': 27.01,
#     'windGustTime': 1560283200,
#     'windBearing': 310,
#     'cloudCover': 0.55,
#     'uvIndex': 7,
#     'uvIndexTime': 1560272400,
#     'visibility': 7.7,
#     'ozone': 330.88,
#     'temperatureMin': 68.52,
#     'temperatureMinTime': 1560308400,
#     'temperatureMax': 79.5,
#     'temperatureMaxTime': 1560283200,
#     'apparentTemperatureMin': 68.52,
#     'apparentTemperatureMinTime': 1560308400,
#     'apparentTemperatureMax': 79.5,
#     'apparentTemperatureMaxTime': 1560283200},
#    {'time': 1560312000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560331560,
#     'sunsetTime': 1560385753,
#     'moonPhase': 0.34,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 79.44,
#     'temperatureHighTime': 1560366000,
#     'temperatureLow': 62.98,
#     'temperatureLowTime': 1560409200,
#     'apparentTemperatureHigh': 79.44,
#     'apparentTemperatureHighTime': 1560366000,
#     'apparentTemperatureLow': 62.98,
#     'apparentTemperatureLowTime': 1560409200,
#     'dewPoint': 42.54,
#     'humidity': 0.39,
#     'pressure': 1020.49,
#     'windSpeed': 1.12,
#     'windGust': 18.24,
#     'windGustTime': 1560391200,
#     'windBearing': 208,
#     'cloudCover': 0.34,
#     'uvIndex': 7,
#     'uvIndexTime': 1560355200,
#     'visibility': 10,
#     'ozone': 335.45,
#     'temperatureMin': 59.28,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 79.44,
#     'temperatureMaxTime': 1560366000,
#     'apparentTemperatureMin': 59.28,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 79.44,
#     'apparentTemperatureMaxTime': 1560366000},
#    {'time': 1560398400,
#     'summary': 'Rain until afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560417956,
#     'sunsetTime': 1560472181,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0218,
#     'precipIntensityMax': 0.0959,
#     'precipIntensityMaxTime': 1560434400,
#     'precipProbability': 0.96,
#     'precipType': 'rain',
#     'temperatureHigh': 66.01,
#     'temperatureHighTime': 1560459600,
#     'temperatureLow': 59.1,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 66.01,
#     'apparentTemperatureHighTime': 1560459600,
#     'apparentTemperatureLow': 59.1,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 55.73,
#     'humidity': 0.75,
#     'pressure': 1014.42,
#     'windSpeed': 7.25,
#     'windGust': 26.35,
#     'windGustTime': 1560438000,
#     'windBearing': 90,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'uvIndexTime': 1560438000,
#     'visibility': 9.77,
#     'ozone': 333.62,
#     'temperatureMin': 61.98,
#     'temperatureMinTime': 1560441600,
#     'temperatureMax': 66.01,
#     'temperatureMaxTime': 1560459600,
#     'apparentTemperatureMin': 61.98,
#     'apparentTemperatureMinTime': 1560441600,
#     'apparentTemperatureMax': 66.01,
#     'apparentTemperatureMaxTime': 1560459600},
#    {'time': 1560484800,
#     'summary': 'Partly cloudy overnight.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560504354,
#     'sunsetTime': 1560558606,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0025,
#     'precipIntensityMax': 0.0098,
#     'precipIntensityMaxTime': 1560513600,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperatureHigh': 78.15,
#     'temperatureHighTime': 1560546000,
#     'temperatureLow': 63.09,
#     'temperatureLowTime': 1560589200,
#     'apparentTemperatureHigh': 78.15,
#     'apparentTemperatureHighTime': 1560546000,
#     'apparentTemperatureLow': 63.09,
#     'apparentTemperatureLowTime': 1560589200,
#     'dewPoint': 50.14,
#     'humidity': 0.53,
#     'pressure': 1014.71,
#     'windSpeed': 3.43,
#     'windGust': 23.49,
#     'windGustTime': 1560495600,
#     'windBearing': 281,
#     'cloudCover': 0.2,
#     'uvIndex': 8,
#     'uvIndexTime': 1560528000,
#     'visibility': 9.96,
#     'ozone': 352.49,
#     'temperatureMin': 59.1,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 78.15,
#     'temperatureMaxTime': 1560546000,
#     'apparentTemperatureMin': 59.1,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 78.15,
#     'apparentTemperatureMaxTime': 1560546000},
#    {'time': 1560571200,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560590754,
#     'sunsetTime': 1560645031,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0007,
#     'precipIntensityMax': 0.0064,
#     'precipIntensityMaxTime': 1560643200,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperatureHigh': 83.54,
#     'temperatureHighTime': 1560628800,
#     'temperatureLow': 67.85,
#     'temperatureLowTime': 1560675600,
#     'apparentTemperatureHigh': 83.54,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 67.85,
#     'apparentTemperatureLowTime': 1560675600,
#     'dewPoint': 55.04,
#     'humidity': 0.53,
#     'pressure': 1018.31,
#     'windSpeed': 6.59,
#     'windGust': 21.62,
#     'windGustTime': 1560585600,
#     'windBearing': 238,
#     'cloudCover': 0.62,
#     'uvIndex': 7,
#     'uvIndexTime': 1560618000,
#     'visibility': 10,
#     'ozone': 344.55,
#     'temperatureMin': 63.09,
#     'temperatureMinTime': 1560589200,
#     'temperatureMax': 83.54,
#     'temperatureMaxTime': 1560628800,
#     'apparentTemperatureMin': 63.09,
#     'apparentTemperatureMinTime': 1560589200,
#     'apparentTemperatureMax': 83.54,
#     'apparentTemperatureMaxTime': 1560628800}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.036,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
JC_current = JC['currently']

# %%
JC_current['windSpeed']
# Out:
# 8.96

# %%
Tem_diff = JC_current['temperature'] - JC_current['apparentTemperature']
Tem_diff
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
Daily1 = JC['daily']['data'][0]
Daily1
# Out:
# {'time': 1559966400,
#  'summary': 'Partly cloudy starting in the evening.',
#  'icon': 'partly-cloudy-night',
#  'sunriseTime': 1559985995,
#  'sunsetTime': 1560040027,
#  'moonPhase': 0.19,
#  'precipIntensity': 0.0003,
#  'precipIntensityMax': 0.0015,
#  'precipIntensityMaxTime': 1560042000,
#  'precipProbability': 0.03,
#  'precipType': 'rain',
#  'temperatureHigh': 81.21,
#  'temperatureHighTime': 1560016800,
#  'temperatureLow': 61.29,
#  'temperatureLowTime': 1560070800,
#  'apparentTemperatureHigh': 81.21,
#  'apparentTemperatureHighTime': 1560016800,
#  'apparentTemperatureLow': 61.29,
#  'apparentTemperatureLowTime': 1560070800,
#  'dewPoint': 52.96,
#  'humidity': 0.56,
#  'pressure': 1019.99,
#  'windSpeed': 4.7,
#  'windGust': 17.98,
#  'windGustTime': 1560042000,
#  'windBearing': 98,
#  'cloudCover': 0.21,
#  'uvIndex': 8,
#  'uvIndexTime': 1560009600,
#  'visibility': 9.62,
#  'ozone': 330.08,
#  'temperatureMin': 62.95,
#  'temperatureMinTime': 1559977200,
#  'temperatureMax': 81.21,
#  'temperatureMaxTime': 1560016800,
#  'apparentTemperatureMin': 63.24,
#  'apparentTemperatureMinTime': 1559977200,
#  'apparentTemperatureMax': 81.21,
#  'apparentTemperatureMaxTime': 1560016800}

# %%
Moon = Daily1['moonPhase']
Moon
# Out:
# 0.19

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
Tem_diff_today = round(Daily1['temperatureHigh'] - Daily1['temperatureLow'],2)
Tem_diff_today
# Out:
# 19.92

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
Daily = JC['daily']['data']
for day in Daily:
    hightemp = day['temperatureHigh']
    if hightemp > 70:
        print(f'The high temperature is {hightemp}, and it is hot.')
    elif hightemp < 45:
        print(f'The high temperature is {hightemp}, and it is cold.')
    else:
        print(f'The high temperature is {hightemp}, and it is warm.')
# Out:
# The high temperature is 81.21, and it is hot.
# The high temperature is 78.2, and it is hot.
# The high temperature is 68.9, and it is warm.
# The high temperature is 79.5, and it is hot.
# The high temperature is 79.44, and it is hot.
# The high temperature is 66.01, and it is warm.
# The high temperature is 78.15, and it is hot.
# The high temperature is 83.54, and it is hot.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
Date = []
HighTemp = []

for day in Daily:
    date = day['time']
    Date.append(date)
    hightemp = day['temperatureHigh']
    HighTemp.append(hightemp)

NextWeek = list(zip(HighTemp,Date))
Hottest = max(NextWeek)

Hottest
# Out:
# (83.54, 1560571200)

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918')
Miami = response.json()
Miami
# Out:
# {'latitude': 25.7617,
#  'longitude': -80.1918,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560027778,
#   'summary': 'Drizzle',
#   'icon': 'rain',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.007,
#   'precipIntensityError': 0.003,
#   'precipProbability': 0.94,
#   'precipType': 'rain',
#   'temperature': 77.19,
#   'apparentTemperature': 78.78,
#   'dewPoint': 73.64,
#   'humidity': 0.89,
#   'pressure': 1014.65,
#   'windSpeed': 4.71,
#   'windGust': 8.59,
#   'windBearing': 243,
#   'cloudCover': 1,
#   'uvIndex': 3,
#   'visibility': 7.32,
#   'ozone': 284.35},
#  'minutely': {'summary': 'Drizzle stopping in 2 min., starting again 25 min. later.',
#   'icon': 'rain',
#   'data': [{'time': 1560027720,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.99,
#     'precipType': 'rain'},
#    {'time': 1560027780,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.94,
#     'precipType': 'rain'},
#    {'time': 1560027840,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.89,
#     'precipType': 'rain'},
#    {'time': 1560027900,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.8,
#     'precipType': 'rain'},
#    {'time': 1560027960,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.74,
#     'precipType': 'rain'},
#    {'time': 1560028020,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.67,
#     'precipType': 'rain'},
#    {'time': 1560028080,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.61,
#     'precipType': 'rain'},
#    {'time': 1560028140,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.003,
#     'precipProbability': 0.56,
#     'precipType': 'rain'},
#    {'time': 1560028200,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.004,
#     'precipProbability': 0.49,
#     'precipType': 'rain'},
#    {'time': 1560028260,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.004,
#     'precipProbability': 0.46,
#     'precipType': 'rain'},
#    {'time': 1560028320,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.41,
#     'precipType': 'rain'},
#    {'time': 1560028380,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.005,
#     'precipProbability': 0.36,
#     'precipType': 'rain'},
#    {'time': 1560028440,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.33,
#     'precipType': 'rain'},
#    {'time': 1560028500,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.009,
#     'precipProbability': 0.27,
#     'precipType': 'rain'},
#    {'time': 1560028560,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1560028620,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.22,
#     'precipType': 'rain'},
#    {'time': 1560028680,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.012,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1560028740,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1560028800,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.013,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560028860,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.013,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560028920,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.015,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1560028980,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.011,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1560029040,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.049,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560029100,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.04,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560029160,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.036,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1560029220,
#     'precipIntensity': 0.016,
#     'precipIntensityError': 0.064,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1560029280,
#     'precipIntensity': 0.02,
#     'precipIntensityError': 0.075,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1560029340,
#     'precipIntensity': 0.019,
#     'precipIntensityError': 0.065,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1560029400,
#     'precipIntensity': 0.026,
#     'precipIntensityError': 0.09,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1560029460,
#     'precipIntensity': 0.029,
#     'precipIntensityError': 0.083,
#     'precipProbability': 0.27,
#     'precipType': 'rain'},
#    {'time': 1560029520,
#     'precipIntensity': 0.036,
#     'precipIntensityError': 0.11,
#     'precipProbability': 0.3,
#     'precipType': 'rain'},
#    {'time': 1560029580,
#     'precipIntensity': 0.042,
#     'precipIntensityError': 0.123,
#     'precipProbability': 0.32,
#     'precipType': 'rain'},
#    {'time': 1560029640,
#     'precipIntensity': 0.049,
#     'precipIntensityError': 0.142,
#     'precipProbability': 0.35,
#     'precipType': 'rain'},
#    {'time': 1560029700,
#     'precipIntensity': 0.05,
#     'precipIntensityError': 0.136,
#     'precipProbability': 0.37,
#     'precipType': 'rain'},
#    {'time': 1560029760,
#     'precipIntensity': 0.057,
#     'precipIntensityError': 0.154,
#     'precipProbability': 0.41,
#     'precipType': 'rain'},
#    {'time': 1560029820,
#     'precipIntensity': 0.063,
#     'precipIntensityError': 0.158,
#     'precipProbability': 0.43,
#     'precipType': 'rain'},
#    {'time': 1560029880,
#     'precipIntensity': 0.065,
#     'precipIntensityError': 0.153,
#     'precipProbability': 0.45,
#     'precipType': 'rain'},
#    {'time': 1560029940,
#     'precipIntensity': 0.069,
#     'precipIntensityError': 0.162,
#     'precipProbability': 0.48,
#     'precipType': 'rain'},
#    {'time': 1560030000,
#     'precipIntensity': 0.074,
#     'precipIntensityError': 0.171,
#     'precipProbability': 0.49,
#     'precipType': 'rain'},
#    {'time': 1560030060,
#     'precipIntensity': 0.075,
#     'precipIntensityError': 0.173,
#     'precipProbability': 0.51,
#     'precipType': 'rain'},
#    {'time': 1560030120,
#     'precipIntensity': 0.077,
#     'precipIntensityError': 0.175,
#     'precipProbability': 0.53,
#     'precipType': 'rain'},
#    {'time': 1560030180,
#     'precipIntensity': 0.075,
#     'precipIntensityError': 0.165,
#     'precipProbability': 0.55,
#     'precipType': 'rain'},
#    {'time': 1560030240,
#     'precipIntensity': 0.083,
#     'precipIntensityError': 0.181,
#     'precipProbability': 0.56,
#     'precipType': 'rain'},
#    {'time': 1560030300,
#     'precipIntensity': 0.085,
#     'precipIntensityError': 0.182,
#     'precipProbability': 0.58,
#     'precipType': 'rain'},
#    {'time': 1560030360,
#     'precipIntensity': 0.078,
#     'precipIntensityError': 0.174,
#     'precipProbability': 0.57,
#     'precipType': 'rain'},
#    {'time': 1560030420,
#     'precipIntensity': 0.087,
#     'precipIntensityError': 0.187,
#     'precipProbability': 0.58,
#     'precipType': 'rain'},
#    {'time': 1560030480,
#     'precipIntensity': 0.089,
#     'precipIntensityError': 0.189,
#     'precipProbability': 0.6,
#     'precipType': 'rain'},
#    {'time': 1560030540,
#     'precipIntensity': 0.086,
#     'precipIntensityError': 0.182,
#     'precipProbability': 0.61,
#     'precipType': 'rain'},
#    {'time': 1560030600,
#     'precipIntensity': 0.081,
#     'precipIntensityError': 0.176,
#     'precipProbability': 0.62,
#     'precipType': 'rain'},
#    {'time': 1560030660,
#     'precipIntensity': 0.088,
#     'precipIntensityError': 0.188,
#     'precipProbability': 0.62,
#     'precipType': 'rain'},
#    {'time': 1560030720,
#     'precipIntensity': 0.083,
#     'precipIntensityError': 0.178,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560030780,
#     'precipIntensity': 0.082,
#     'precipIntensityError': 0.178,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560030840,
#     'precipIntensity': 0.084,
#     'precipIntensityError': 0.18,
#     'precipProbability': 0.64,
#     'precipType': 'rain'},
#    {'time': 1560030900,
#     'precipIntensity': 0.085,
#     'precipIntensityError': 0.181,
#     'precipProbability': 0.64,
#     'precipType': 'rain'},
#    {'time': 1560030960,
#     'precipIntensity': 0.084,
#     'precipIntensityError': 0.181,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560031020,
#     'precipIntensity': 0.084,
#     'precipIntensityError': 0.177,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560031080,
#     'precipIntensity': 0.085,
#     'precipIntensityError': 0.178,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560031140,
#     'precipIntensity': 0.08,
#     'precipIntensityError': 0.17,
#     'precipProbability': 0.62,
#     'precipType': 'rain'},
#    {'time': 1560031200,
#     'precipIntensity': 0.081,
#     'precipIntensityError': 0.173,
#     'precipProbability': 0.63,
#     'precipType': 'rain'},
#    {'time': 1560031260,
#     'precipIntensity': 0.083,
#     'precipIntensityError': 0.177,
#     'precipProbability': 0.64,
#     'precipType': 'rain'},
#    {'time': 1560031320,
#     'precipIntensity': 0.08,
#     'precipIntensityError': 0.17,
#     'precipProbability': 0.62,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Light rain later this evening and tomorrow afternoon.',
#   'icon': 'rain',
#   'data': [{'time': 1560027600,
#     'summary': 'Drizzle',
#     'icon': 'rain',
#     'precipIntensity': 0.0037,
#     'precipProbability': 0.99,
#     'precipType': 'rain',
#     'temperature': 77.18,
#     'apparentTemperature': 78.77,
#     'dewPoint': 73.64,
#     'humidity': 0.89,
#     'pressure': 1014.68,
#     'windSpeed': 4.87,
#     'windGust': 8.58,
#     'windBearing': 245,
#     'cloudCover': 1,
#     'uvIndex': 3,
#     'visibility': 7.22,
#     'ozone': 284.3},
#    {'time': 1560031200,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0396,
#     'precipProbability': 0.64,
#     'precipType': 'rain',
#     'temperature': 77.44,
#     'apparentTemperature': 79,
#     'dewPoint': 73.5,
#     'humidity': 0.88,
#     'pressure': 1014.25,
#     'windSpeed': 3.35,
#     'windGust': 8.87,
#     'windBearing': 184,
#     'cloudCover': 0.93,
#     'uvIndex': 2,
#     'visibility': 9.35,
#     'ozone': 285.44},
#    {'time': 1560034800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.06,
#     'apparentTemperature': 87.84,
#     'dewPoint': 73.57,
#     'humidity': 0.76,
#     'pressure': 1013.52,
#     'windSpeed': 7.19,
#     'windGust': 9.31,
#     'windBearing': 169,
#     'cloudCover': 0.66,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.14},
#    {'time': 1560038400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0049,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 84.64,
#     'apparentTemperature': 91.89,
#     'dewPoint': 73.76,
#     'humidity': 0.7,
#     'pressure': 1013.34,
#     'windSpeed': 9.56,
#     'windGust': 12.18,
#     'windBearing': 172,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 288.64},
#    {'time': 1560042000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 83.55,
#     'apparentTemperature': 90.73,
#     'dewPoint': 74.33,
#     'humidity': 0.74,
#     'pressure': 1013.83,
#     'windSpeed': 9.19,
#     'windGust': 11.98,
#     'windBearing': 173,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.81},
#    {'time': 1560045600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 82.99,
#     'apparentTemperature': 90.34,
#     'dewPoint': 74.99,
#     'humidity': 0.77,
#     'pressure': 1014.31,
#     'windSpeed': 8.87,
#     'windGust': 11.36,
#     'windBearing': 175,
#     'cloudCover': 0.56,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.83},
#    {'time': 1560049200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0018,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 82.35,
#     'apparentTemperature': 89.52,
#     'dewPoint': 75.35,
#     'humidity': 0.79,
#     'pressure': 1014.67,
#     'windSpeed': 8.53,
#     'windGust': 10.65,
#     'windBearing': 179,
#     'cloudCover': 0.57,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.87},
#    {'time': 1560052800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 81.82,
#     'apparentTemperature': 88.68,
#     'dewPoint': 75.53,
#     'humidity': 0.81,
#     'pressure': 1014.7,
#     'windSpeed': 8.4,
#     'windGust': 10.85,
#     'windBearing': 182,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 292.86},
#    {'time': 1560056400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 81.47,
#     'apparentTemperature': 88.12,
#     'dewPoint': 75.68,
#     'humidity': 0.83,
#     'pressure': 1014.53,
#     'windSpeed': 8.42,
#     'windGust': 11.58,
#     'windBearing': 183,
#     'cloudCover': 0.23,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 293.94},
#    {'time': 1560060000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 79.74,
#     'apparentTemperature': 84.62,
#     'dewPoint': 75.74,
#     'humidity': 0.88,
#     'pressure': 1014.37,
#     'windSpeed': 8.28,
#     'windGust': 11.81,
#     'windBearing': 184,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.84},
#    {'time': 1560063600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 78.2,
#     'apparentTemperature': 81.03,
#     'dewPoint': 75.78,
#     'humidity': 0.92,
#     'pressure': 1014.25,
#     'windSpeed': 8.1,
#     'windGust': 11.47,
#     'windBearing': 184,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 295.68},
#    {'time': 1560067200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 77.83,
#     'apparentTemperature': 79.71,
#     'dewPoint': 75.81,
#     'humidity': 0.94,
#     'pressure': 1014.11,
#     'windSpeed': 7.96,
#     'windGust': 11.64,
#     'windBearing': 184,
#     'cloudCover': 0.22,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.52},
#    {'time': 1560070800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0037,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 77.91,
#     'apparentTemperature': 79.78,
#     'dewPoint': 75.76,
#     'humidity': 0.93,
#     'pressure': 1014.11,
#     'windSpeed': 8.46,
#     'windGust': 12.78,
#     'windBearing': 185,
#     'cloudCover': 0.22,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.32},
#    {'time': 1560074400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 78.11,
#     'apparentTemperature': 79.96,
#     'dewPoint': 75.72,
#     'humidity': 0.92,
#     'pressure': 1014.15,
#     'windSpeed': 8.8,
#     'windGust': 13.16,
#     'windBearing': 187,
#     'cloudCover': 0.16,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.89},
#    {'time': 1560078000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 78.71,
#     'apparentTemperature': 82.15,
#     'dewPoint': 75.11,
#     'humidity': 0.89,
#     'pressure': 1014.46,
#     'windSpeed': 9.65,
#     'windGust': 13.62,
#     'windBearing': 192,
#     'cloudCover': 0.2,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.42},
#    {'time': 1560081600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 79.76,
#     'apparentTemperature': 84.34,
#     'dewPoint': 74.85,
#     'humidity': 0.85,
#     'pressure': 1014.82,
#     'windSpeed': 10.15,
#     'windGust': 14.03,
#     'windBearing': 191,
#     'cloudCover': 0.18,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 298.85},
#    {'time': 1560085200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0052,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 82.02,
#     'apparentTemperature': 88.34,
#     'dewPoint': 74.46,
#     'humidity': 0.78,
#     'pressure': 1015.25,
#     'windSpeed': 10.15,
#     'windGust': 13.15,
#     'windBearing': 190,
#     'cloudCover': 0.14,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 299.25},
#    {'time': 1560088800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0146,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 84.03,
#     'apparentTemperature': 91.17,
#     'dewPoint': 73.97,
#     'humidity': 0.72,
#     'pressure': 1015.73,
#     'windSpeed': 9.89,
#     'windGust': 11.51,
#     'windBearing': 186,
#     'cloudCover': 0.08,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 299.54},
#    {'time': 1560092400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0242,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 85.6,
#     'apparentTemperature': 93.13,
#     'dewPoint': 73.62,
#     'humidity': 0.68,
#     'pressure': 1016.05,
#     'windSpeed': 9.81,
#     'windGust': 10.44,
#     'windBearing': 182,
#     'cloudCover': 0.07,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 299.75},
#    {'time': 1560096000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0235,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 86.95,
#     'apparentTemperature': 94.89,
#     'dewPoint': 73.53,
#     'humidity': 0.65,
#     'pressure': 1016.19,
#     'windSpeed': 10.28,
#     'windGust': 10.67,
#     'windBearing': 178,
#     'cloudCover': 0.16,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 299.69},
#    {'time': 1560099600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0221,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 89.43,
#     'apparentTemperature': 98.25,
#     'dewPoint': 73.59,
#     'humidity': 0.6,
#     'pressure': 1016.17,
#     'windSpeed': 10.93,
#     'windGust': 11.61,
#     'windBearing': 174,
#     'cloudCover': 0.29,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 299.52},
#    {'time': 1560103200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0242,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 90.76,
#     'apparentTemperature': 100.16,
#     'dewPoint': 73.75,
#     'humidity': 0.58,
#     'pressure': 1016.07,
#     'windSpeed': 11.36,
#     'windGust': 12.56,
#     'windBearing': 170,
#     'cloudCover': 0.41,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 299.08},
#    {'time': 1560106800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0267,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'temperature': 90.35,
#     'apparentTemperature': 99.75,
#     'dewPoint': 73.87,
#     'humidity': 0.59,
#     'pressure': 1015.86,
#     'windSpeed': 11.34,
#     'windGust': 13.4,
#     'windBearing': 165,
#     'cloudCover': 0.46,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 298.45},
#    {'time': 1560110400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0354,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 88.98,
#     'apparentTemperature': 98.13,
#     'dewPoint': 74.03,
#     'humidity': 0.62,
#     'pressure': 1015.56,
#     'windSpeed': 11.05,
#     'windGust': 14.22,
#     'windBearing': 161,
#     'cloudCover': 0.52,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 297.63},
#    {'time': 1560114000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0409,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'temperature': 87.45,
#     'apparentTemperature': 96.25,
#     'dewPoint': 74.2,
#     'humidity': 0.65,
#     'pressure': 1015.38,
#     'windSpeed': 10.59,
#     'windGust': 14.64,
#     'windBearing': 160,
#     'cloudCover': 0.57,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 297.13},
#    {'time': 1560117600,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0458,
#     'precipProbability': 0.25,
#     'precipType': 'rain',
#     'temperature': 86.04,
#     'apparentTemperature': 94.54,
#     'dewPoint': 74.46,
#     'humidity': 0.69,
#     'pressure': 1015.34,
#     'windSpeed': 9.97,
#     'windGust': 14.58,
#     'windBearing': 164,
#     'cloudCover': 0.6,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 297.27},
#    {'time': 1560121200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1055,
#     'precipProbability': 0.39,
#     'precipType': 'rain',
#     'temperature': 84.49,
#     'apparentTemperature': 92.51,
#     'dewPoint': 74.73,
#     'humidity': 0.73,
#     'pressure': 1015.42,
#     'windSpeed': 9.21,
#     'windGust': 14.2,
#     'windBearing': 172,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.67},
#    {'time': 1560124800,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1606,
#     'precipProbability': 0.43,
#     'precipType': 'rain',
#     'temperature': 83.42,
#     'apparentTemperature': 90.99,
#     'dewPoint': 74.93,
#     'humidity': 0.76,
#     'pressure': 1015.61,
#     'windSpeed': 8.47,
#     'windGust': 13.27,
#     'windBearing': 177,
#     'cloudCover': 0.65,
#     'uvIndex': 0,
#     'visibility': 9.6,
#     'ozone': 298.49},
#    {'time': 1560128400,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1034,
#     'precipProbability': 0.34,
#     'precipType': 'rain',
#     'temperature': 82.83,
#     'apparentTemperature': 90.05,
#     'dewPoint': 74.96,
#     'humidity': 0.77,
#     'pressure': 1016.04,
#     'windSpeed': 7.62,
#     'windGust': 11.14,
#     'windBearing': 177,
#     'cloudCover': 0.67,
#     'uvIndex': 0,
#     'visibility': 9.23,
#     'ozone': 300.14},
#    {'time': 1560132000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0301,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperature': 82.68,
#     'apparentTemperature': 89.73,
#     'dewPoint': 74.88,
#     'humidity': 0.77,
#     'pressure': 1016.56,
#     'windSpeed': 6.72,
#     'windGust': 8.41,
#     'windBearing': 177,
#     'cloudCover': 0.68,
#     'uvIndex': 0,
#     'visibility': 9.09,
#     'ozone': 302.18},
#    {'time': 1560135600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0103,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 82.37,
#     'apparentTemperature': 89.19,
#     'dewPoint': 74.85,
#     'humidity': 0.78,
#     'pressure': 1016.9,
#     'windSpeed': 6.18,
#     'windGust': 6.63,
#     'windBearing': 178,
#     'cloudCover': 0.67,
#     'uvIndex': 0,
#     'visibility': 9.19,
#     'ozone': 303.1},
#    {'time': 1560139200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.006,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 81.73,
#     'apparentTemperature': 88.11,
#     'dewPoint': 74.88,
#     'humidity': 0.8,
#     'pressure': 1016.83,
#     'windSpeed': 6.38,
#     'windGust': 6.65,
#     'windBearing': 178,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 9.49,
#     'ozone': 302.03},
#    {'time': 1560142800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0028,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 81.13,
#     'apparentTemperature': 87.07,
#     'dewPoint': 74.98,
#     'humidity': 0.82,
#     'pressure': 1016.56,
#     'windSpeed': 7.01,
#     'windGust': 7.49,
#     'windBearing': 177,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.95},
#    {'time': 1560146400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 78.99,
#     'apparentTemperature': 82.79,
#     'dewPoint': 75.06,
#     'humidity': 0.88,
#     'pressure': 1016.28,
#     'windSpeed': 7.56,
#     'windGust': 8.39,
#     'windBearing': 176,
#     'cloudCover': 0.51,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.44},
#    {'time': 1560150000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 77.13,
#     'apparentTemperature': 78.95,
#     'dewPoint': 75.18,
#     'humidity': 0.94,
#     'pressure': 1015.97,
#     'windSpeed': 7.85,
#     'windGust': 9.44,
#     'windBearing': 175,
#     'cloudCover': 0.52,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.31},
#    {'time': 1560153600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0022,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 76.84,
#     'apparentTemperature': 78.7,
#     'dewPoint': 75.31,
#     'humidity': 0.95,
#     'pressure': 1015.66,
#     'windSpeed': 8.04,
#     'windGust': 10.62,
#     'windBearing': 172,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.6},
#    {'time': 1560157200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0026,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 77.09,
#     'apparentTemperature': 78.93,
#     'dewPoint': 75.34,
#     'humidity': 0.94,
#     'pressure': 1015.59,
#     'windSpeed': 8.1,
#     'windGust': 11.32,
#     'windBearing': 172,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.9},
#    {'time': 1560160800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 77.89,
#     'apparentTemperature': 79.69,
#     'dewPoint': 75.29,
#     'humidity': 0.92,
#     'pressure': 1015.86,
#     'windSpeed': 7.99,
#     'windGust': 11.12,
#     'windBearing': 173,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.81},
#    {'time': 1560164400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0008,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 79,
#     'apparentTemperature': 82.82,
#     'dewPoint': 75.13,
#     'humidity': 0.88,
#     'pressure': 1016.34,
#     'windSpeed': 7.76,
#     'windGust': 10.43,
#     'windBearing': 175,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.54},
#    {'time': 1560168000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 80.51,
#     'apparentTemperature': 85.84,
#     'dewPoint': 74.87,
#     'humidity': 0.83,
#     'pressure': 1016.85,
#     'windSpeed': 7.65,
#     'windGust': 9.87,
#     'windBearing': 177,
#     'cloudCover': 0.59,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 298.36},
#    {'time': 1560171600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 82.64,
#     'apparentTemperature': 89.36,
#     'dewPoint': 74.44,
#     'humidity': 0.76,
#     'pressure': 1017.39,
#     'windSpeed': 7.78,
#     'windGust': 9.69,
#     'windBearing': 179,
#     'cloudCover': 0.68,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 298.19},
#    {'time': 1560175200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0028,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 84.36,
#     'apparentTemperature': 91.62,
#     'dewPoint': 73.92,
#     'humidity': 0.71,
#     'pressure': 1017.96,
#     'windSpeed': 8.04,
#     'windGust': 9.65,
#     'windBearing': 182,
#     'cloudCover': 0.81,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 298.1},
#    {'time': 1560178800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0047,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 85.5,
#     'apparentTemperature': 92.91,
#     'dewPoint': 73.52,
#     'humidity': 0.68,
#     'pressure': 1018.31,
#     'windSpeed': 8.4,
#     'windGust': 9.8,
#     'windBearing': 182,
#     'cloudCover': 0.88,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 297.82},
#    {'time': 1560182400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0066,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 86.86,
#     'apparentTemperature': 94.61,
#     'dewPoint': 73.35,
#     'humidity': 0.64,
#     'pressure': 1018.33,
#     'windSpeed': 8.89,
#     'windGust': 10.03,
#     'windBearing': 179,
#     'cloudCover': 0.81,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 297.36},
#    {'time': 1560186000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0114,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 89.51,
#     'apparentTemperature': 98.04,
#     'dewPoint': 73.3,
#     'humidity': 0.59,
#     'pressure': 1018.11,
#     'windSpeed': 9.46,
#     'windGust': 10.4,
#     'windBearing': 174,
#     'cloudCover': 0.7,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 296.64},
#    {'time': 1560189600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.015,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 90.85,
#     'apparentTemperature': 99.8,
#     'dewPoint': 73.32,
#     'humidity': 0.57,
#     'pressure': 1017.75,
#     'windSpeed': 9.82,
#     'windGust': 10.77,
#     'windBearing': 170,
#     'cloudCover': 0.61,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 296.04},
#    {'time': 1560193200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0129,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 90.46,
#     'apparentTemperature': 99.37,
#     'dewPoint': 73.39,
#     'humidity': 0.58,
#     'pressure': 1017.13,
#     'windSpeed': 9.88,
#     'windGust': 11.21,
#     'windBearing': 170,
#     'cloudCover': 0.61,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 295.47},
#    {'time': 1560196800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 89.38,
#     'apparentTemperature': 98.07,
#     'dewPoint': 73.49,
#     'humidity': 0.6,
#     'pressure': 1016.35,
#     'windSpeed': 9.74,
#     'windGust': 11.66,
#     'windBearing': 172,
#     'cloudCover': 0.62,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 294.83},
#    {'time': 1560200400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0195,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 88,
#     'apparentTemperature': 96.35,
#     'dewPoint': 73.58,
#     'humidity': 0.63,
#     'pressure': 1015.82,
#     'windSpeed': 9.48,
#     'windGust': 11.96,
#     'windBearing': 173,
#     'cloudCover': 0.63,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 294.25}]},
#  'daily': {'summary': 'Rain today through Tuesday, with high temperatures peaking at 91°F on Thursday.',
#   'icon': 'rain',
#   'data': [{'time': 1559966400,
#     'summary': 'Rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1559989815,
#     'sunsetTime': 1560039142,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.0121,
#     'precipIntensityMax': 0.1381,
#     'precipIntensityMaxTime': 1560020400,
#     'precipProbability': 0.99,
#     'precipType': 'rain',
#     'temperatureHigh': 88.94,
#     'temperatureHighTime': 1560009600,
#     'temperatureLow': 77.83,
#     'temperatureLowTime': 1560067200,
#     'apparentTemperatureHigh': 97.44,
#     'apparentTemperatureHighTime': 1560009600,
#     'apparentTemperatureLow': 79.71,
#     'apparentTemperatureLowTime': 1560067200,
#     'dewPoint': 75.02,
#     'humidity': 0.82,
#     'pressure': 1013.53,
#     'windSpeed': 6.01,
#     'windGust': 12.18,
#     'windGustTime': 1560038400,
#     'windBearing': 185,
#     'cloudCover': 0.56,
#     'uvIndex': 7,
#     'uvIndexTime': 1560006000,
#     'visibility': 9.2,
#     'ozone': 285.26,
#     'temperatureMin': 77.16,
#     'temperatureMinTime': 1559991600,
#     'temperatureMax': 88.94,
#     'temperatureMaxTime': 1560009600,
#     'apparentTemperatureMin': 78.77,
#     'apparentTemperatureMinTime': 1560027600,
#     'apparentTemperatureMax': 97.44,
#     'apparentTemperatureMaxTime': 1560009600},
#    {'time': 1560052800,
#     'summary': 'Rain starting in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560076214,
#     'sunsetTime': 1560125565,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0286,
#     'precipIntensityMax': 0.1606,
#     'precipIntensityMaxTime': 1560124800,
#     'precipProbability': 0.83,
#     'precipType': 'rain',
#     'temperatureHigh': 90.76,
#     'temperatureHighTime': 1560103200,
#     'temperatureLow': 76.84,
#     'temperatureLowTime': 1560153600,
#     'apparentTemperatureHigh': 100.16,
#     'apparentTemperatureHighTime': 1560103200,
#     'apparentTemperatureLow': 78.7,
#     'apparentTemperatureLowTime': 1560153600,
#     'dewPoint': 74.74,
#     'humidity': 0.76,
#     'pressure': 1015.32,
#     'windSpeed': 9.12,
#     'windGust': 14.64,
#     'windGustTime': 1560114000,
#     'windBearing': 178,
#     'cloudCover': 0.35,
#     'uvIndex': 9,
#     'uvIndexTime': 1560096000,
#     'visibility': 9.88,
#     'ozone': 298.13,
#     'temperatureMin': 77.83,
#     'temperatureMinTime': 1560067200,
#     'temperatureMax': 90.76,
#     'temperatureMaxTime': 1560103200,
#     'apparentTemperatureMin': 79.71,
#     'apparentTemperatureMinTime': 1560067200,
#     'apparentTemperatureMax': 100.16,
#     'apparentTemperatureMaxTime': 1560103200},
#    {'time': 1560139200,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560162614,
#     'sunsetTime': 1560211987,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.006,
#     'precipIntensityMax': 0.0195,
#     'precipIntensityMaxTime': 1560200400,
#     'precipProbability': 0.5,
#     'precipType': 'rain',
#     'temperatureHigh': 90.85,
#     'temperatureHighTime': 1560189600,
#     'temperatureLow': 77.26,
#     'temperatureLowTime': 1560243600,
#     'apparentTemperatureHigh': 99.8,
#     'apparentTemperatureHighTime': 1560189600,
#     'apparentTemperatureLow': 78.72,
#     'apparentTemperatureLowTime': 1560243600,
#     'dewPoint': 74.15,
#     'humidity': 0.74,
#     'pressure': 1016.73,
#     'windSpeed': 8.25,
#     'windGust': 12.07,
#     'windGustTime': 1560204000,
#     'windBearing': 176,
#     'cloudCover': 0.61,
#     'uvIndex': 7,
#     'uvIndexTime': 1560186000,
#     'visibility': 9.98,
#     'ozone': 296.41,
#     'temperatureMin': 76.84,
#     'temperatureMinTime': 1560153600,
#     'temperatureMax': 90.85,
#     'temperatureMaxTime': 1560189600,
#     'apparentTemperatureMin': 78.7,
#     'apparentTemperatureMinTime': 1560153600,
#     'apparentTemperatureMax': 99.8,
#     'apparentTemperatureMaxTime': 1560189600},
#    {'time': 1560225600,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560249015,
#     'sunsetTime': 1560298409,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0047,
#     'precipIntensityMax': 0.0275,
#     'precipIntensityMaxTime': 1560286800,
#     'precipProbability': 0.35,
#     'precipType': 'rain',
#     'temperatureHigh': 90.99,
#     'temperatureHighTime': 1560276000,
#     'temperatureLow': 78.46,
#     'temperatureLowTime': 1560326400,
#     'apparentTemperatureHigh': 98.36,
#     'apparentTemperatureHighTime': 1560276000,
#     'apparentTemperatureLow': 79.78,
#     'apparentTemperatureLowTime': 1560326400,
#     'dewPoint': 72.67,
#     'humidity': 0.7,
#     'pressure': 1016.35,
#     'windSpeed': 6.4,
#     'windGust': 14.45,
#     'windGustTime': 1560290400,
#     'windBearing': 179,
#     'cloudCover': 0.48,
#     'uvIndex': 9,
#     'uvIndexTime': 1560268800,
#     'visibility': 10,
#     'ozone': 293.24,
#     'temperatureMin': 77.26,
#     'temperatureMinTime': 1560243600,
#     'temperatureMax': 90.99,
#     'temperatureMaxTime': 1560276000,
#     'apparentTemperatureMin': 78.72,
#     'apparentTemperatureMinTime': 1560243600,
#     'apparentTemperatureMax': 98.36,
#     'apparentTemperatureMaxTime': 1560276000},
#    {'time': 1560312000,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560335417,
#     'sunsetTime': 1560384830,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0008,
#     'precipIntensityMax': 0.0045,
#     'precipIntensityMaxTime': 1560373200,
#     'precipProbability': 0.29,
#     'precipType': 'rain',
#     'temperatureHigh': 91.01,
#     'temperatureHighTime': 1560362400,
#     'temperatureLow': 79.53,
#     'temperatureLowTime': 1560420000,
#     'apparentTemperatureHigh': 97.68,
#     'apparentTemperatureHighTime': 1560362400,
#     'apparentTemperatureLow': 82.91,
#     'apparentTemperatureLowTime': 1560416400,
#     'dewPoint': 71.85,
#     'humidity': 0.67,
#     'pressure': 1015.73,
#     'windSpeed': 7.5,
#     'windGust': 17.13,
#     'windGustTime': 1560384000,
#     'windBearing': 158,
#     'cloudCover': 0.7,
#     'uvIndex': 5,
#     'uvIndexTime': 1560355200,
#     'visibility': 10,
#     'ozone': 301.15,
#     'temperatureMin': 78.46,
#     'temperatureMinTime': 1560326400,
#     'temperatureMax': 91.01,
#     'temperatureMaxTime': 1560362400,
#     'apparentTemperatureMin': 79.78,
#     'apparentTemperatureMinTime': 1560326400,
#     'apparentTemperatureMax': 97.68,
#     'apparentTemperatureMaxTime': 1560362400},
#    {'time': 1560398400,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560421821,
#     'sunsetTime': 1560471250,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0067,
#     'precipIntensityMax': 0.0215,
#     'precipIntensityMaxTime': 1560405600,
#     'precipProbability': 0.76,
#     'precipType': 'rain',
#     'temperatureHigh': 91.23,
#     'temperatureHighTime': 1560456000,
#     'temperatureLow': 78.06,
#     'temperatureLowTime': 1560499200,
#     'apparentTemperatureHigh': 98.06,
#     'apparentTemperatureHighTime': 1560456000,
#     'apparentTemperatureLow': 79.42,
#     'apparentTemperatureLowTime': 1560499200,
#     'dewPoint': 71.41,
#     'humidity': 0.65,
#     'pressure': 1016.58,
#     'windSpeed': 9.02,
#     'windGust': 17.25,
#     'windGustTime': 1560456000,
#     'windBearing': 187,
#     'cloudCover': 0.74,
#     'uvIndex': 8,
#     'uvIndexTime': 1560441600,
#     'visibility': 9.98,
#     'ozone': 283.16,
#     'temperatureMin': 79.53,
#     'temperatureMinTime': 1560420000,
#     'temperatureMax': 91.23,
#     'temperatureMaxTime': 1560456000,
#     'apparentTemperatureMin': 82.91,
#     'apparentTemperatureMinTime': 1560416400,
#     'apparentTemperatureMax': 98.06,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560484800,
#     'summary': 'Humid and overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560508225,
#     'sunsetTime': 1560557669,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0026,
#     'precipIntensityMax': 0.0153,
#     'precipIntensityMaxTime': 1560492000,
#     'precipProbability': 0.4,
#     'precipType': 'rain',
#     'temperatureHigh': 89.7,
#     'temperatureHighTime': 1560535200,
#     'temperatureLow': 78.37,
#     'temperatureLowTime': 1560589200,
#     'apparentTemperatureHigh': 97.2,
#     'apparentTemperatureHighTime': 1560535200,
#     'apparentTemperatureLow': 79.94,
#     'apparentTemperatureLowTime': 1560589200,
#     'dewPoint': 72.42,
#     'humidity': 0.69,
#     'pressure': 1017.82,
#     'windSpeed': 6.11,
#     'windGust': 14.63,
#     'windGustTime': 1560567600,
#     'windBearing': 145,
#     'cloudCover': 0.94,
#     'uvIndex': 6,
#     'uvIndexTime': 1560528000,
#     'visibility': 10,
#     'ozone': 280.65,
#     'temperatureMin': 78.06,
#     'temperatureMinTime': 1560499200,
#     'temperatureMax': 89.7,
#     'temperatureMaxTime': 1560535200,
#     'apparentTemperatureMin': 79.42,
#     'apparentTemperatureMinTime': 1560499200,
#     'apparentTemperatureMax': 97.2,
#     'apparentTemperatureMaxTime': 1560535200},
#    {'time': 1560571200,
#     'summary': 'Humid and overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560594631,
#     'sunsetTime': 1560644088,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0036,
#     'precipIntensityMax': 0.0221,
#     'precipIntensityMaxTime': 1560589200,
#     'precipProbability': 0.61,
#     'precipType': 'rain',
#     'temperatureHigh': 88.11,
#     'temperatureHighTime': 1560625200,
#     'temperatureLow': 78.32,
#     'temperatureLowTime': 1560672000,
#     'apparentTemperatureHigh': 95.24,
#     'apparentTemperatureHighTime': 1560621600,
#     'apparentTemperatureLow': 79.83,
#     'apparentTemperatureLowTime': 1560672000,
#     'dewPoint': 73.46,
#     'humidity': 0.74,
#     'pressure': 1018.3,
#     'windSpeed': 10.02,
#     'windGust': 15.24,
#     'windGustTime': 1560574800,
#     'windBearing': 113,
#     'cloudCover': 1,
#     'uvIndex': 5,
#     'uvIndexTime': 1560614400,
#     'visibility': 9.58,
#     'ozone': 289.58,
#     'temperatureMin': 78.37,
#     'temperatureMinTime': 1560589200,
#     'temperatureMax': 88.11,
#     'temperatureMaxTime': 1560625200,
#     'apparentTemperatureMin': 79.94,
#     'apparentTemperatureMinTime': 1560589200,
#     'apparentTemperatureMax': 95.24,
#     'apparentTemperatureMaxTime': 1560621600}]},
#  'alerts': [{'title': 'Flood Advisory',
#    'regions': ['Broward', 'Miami-Dade'],
#    'severity': 'advisory',
#    'time': 1560023940,
#    'expires': 1560028500,
#    'description': 'The National Weather Service in Miami has extended the * Flood Advisory for... Northern Miami-Dade County in southeastern Florida... Southern Broward County in southeastern Florida... * Until 515 PM EDT. * At 358 PM EDT, Doppler radar indicated heavy rain due to thunderstorms. This will cause minor flooding in the advisory area. Up to three inches of rain have already fallen. Another 1 inch of rain is possible over the next hour. * Some locations that will experience flooding include... Fort Lauderdale, Pembroke Pines, Hollywood, Miramar and Davie.\n',
#    'uri': 'https://alerts.weather.gov/cap/wwacapget.php?x=FL125CFE07813C.FloodAdvisory.125CFE07BE2CFL.MFLFLSMFL.9e349dd5a1e415d7dc3b4be1b5324b1e'},
#   {'title': 'Flood Advisory',
#    'regions': ['Miami-Dade'],
#    'severity': 'advisory',
#    'time': 1560023940,
#    'expires': 1560028500,
#    'description': 'The National Weather Service in Miami has issued a * Flood Advisory for... Northern Miami-Dade County in southeastern Florida... * Until 500 PM EDT. * At 358 PM EDT, Doppler radar indicated heavy rain due to thunderstorms. This will cause minor flooding in the advisory area. * Some locations that will experience flooding include... Miami, Hialeah, Doral, Miami Springs and Sweetwater.\n',
#    'uri': 'https://alerts.weather.gov/cap/wwacapget.php?x=FL125CFE0780D8.FloodAdvisory.125CFE07BE2CFL.MFLFLSMFL.414da562430d7b505c80a20986918744'},
#   {'title': 'Flood Advisory',
#    'regions': ['Miami-Dade'],
#    'severity': 'advisory',
#    'time': 1560023940,
#    'expires': 1560028500,
#    'description': 'The National Weather Service in Miami has issued a * Flood Advisory for... Central Miami-Dade County in southeastern Florida... * Until 645 PM EDT. * At 350 PM EDT, Doppler radar indicated heavy rain due to thunderstorms. This will cause minor flooding in the advisory area. Up to two inches of rain have already fallen. * Some locations that will experience flooding include... Coral Gables, South Miami, Black Point, Kendall and Pinecrest. Additional rainfall of around 1 inch is expected over the area over the next two hours.\n',
#    'uri': 'https://alerts.weather.gov/cap/wwacapget.php?x=FL125CFE077E1C.FloodAdvisory.125CFE07BE2CFL.MFLFLSMFL.cf38e0bea1ad6d52f9dd1400a7e56006'}],
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.805,
#   'units': 'us'},
#  'offset': -4}

# %%
Miami24 = Miami['hourly']['data']
Miami24
# Out:
# [{'time': 1560027600,
#   'summary': 'Drizzle',
#   'icon': 'rain',
#   'precipIntensity': 0.0037,
#   'precipProbability': 0.99,
#   'precipType': 'rain',
#   'temperature': 77.18,
#   'apparentTemperature': 78.77,
#   'dewPoint': 73.64,
#   'humidity': 0.89,
#   'pressure': 1014.68,
#   'windSpeed': 4.87,
#   'windGust': 8.58,
#   'windBearing': 245,
#   'cloudCover': 1,
#   'uvIndex': 3,
#   'visibility': 7.22,
#   'ozone': 284.3},
#  {'time': 1560031200,
#   'summary': 'Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0396,
#   'precipProbability': 0.64,
#   'precipType': 'rain',
#   'temperature': 77.44,
#   'apparentTemperature': 79,
#   'dewPoint': 73.5,
#   'humidity': 0.88,
#   'pressure': 1014.25,
#   'windSpeed': 3.35,
#   'windGust': 8.87,
#   'windBearing': 184,
#   'cloudCover': 0.93,
#   'uvIndex': 2,
#   'visibility': 9.35,
#   'ozone': 285.44},
#  {'time': 1560034800,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 82.06,
#   'apparentTemperature': 87.84,
#   'dewPoint': 73.57,
#   'humidity': 0.76,
#   'pressure': 1013.52,
#   'windSpeed': 7.19,
#   'windGust': 9.31,
#   'windBearing': 169,
#   'cloudCover': 0.66,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 287.14},
#  {'time': 1560038400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0049,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 84.64,
#   'apparentTemperature': 91.89,
#   'dewPoint': 73.76,
#   'humidity': 0.7,
#   'pressure': 1013.34,
#   'windSpeed': 9.56,
#   'windGust': 12.18,
#   'windBearing': 172,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.64},
#  {'time': 1560042000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0038,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 83.55,
#   'apparentTemperature': 90.73,
#   'dewPoint': 74.33,
#   'humidity': 0.74,
#   'pressure': 1013.83,
#   'windSpeed': 9.19,
#   'windGust': 11.98,
#   'windBearing': 173,
#   'cloudCover': 0.43,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.81},
#  {'time': 1560045600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0023,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 82.99,
#   'apparentTemperature': 90.34,
#   'dewPoint': 74.99,
#   'humidity': 0.77,
#   'pressure': 1014.31,
#   'windSpeed': 8.87,
#   'windGust': 11.36,
#   'windBearing': 175,
#   'cloudCover': 0.56,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.83},
#  {'time': 1560049200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0018,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 82.35,
#   'apparentTemperature': 89.52,
#   'dewPoint': 75.35,
#   'humidity': 0.79,
#   'pressure': 1014.67,
#   'windSpeed': 8.53,
#   'windGust': 10.65,
#   'windBearing': 179,
#   'cloudCover': 0.57,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.87},
#  {'time': 1560052800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0016,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 81.82,
#   'apparentTemperature': 88.68,
#   'dewPoint': 75.53,
#   'humidity': 0.81,
#   'pressure': 1014.7,
#   'windSpeed': 8.4,
#   'windGust': 10.85,
#   'windBearing': 182,
#   'cloudCover': 0.47,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.86},
#  {'time': 1560056400,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0006,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 81.47,
#   'apparentTemperature': 88.12,
#   'dewPoint': 75.68,
#   'humidity': 0.83,
#   'pressure': 1014.53,
#   'windSpeed': 8.42,
#   'windGust': 11.58,
#   'windBearing': 183,
#   'cloudCover': 0.23,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 293.94},
#  {'time': 1560060000,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0007,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 79.74,
#   'apparentTemperature': 84.62,
#   'dewPoint': 75.74,
#   'humidity': 0.88,
#   'pressure': 1014.37,
#   'windSpeed': 8.28,
#   'windGust': 11.81,
#   'windBearing': 184,
#   'cloudCover': 0.08,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.84},
#  {'time': 1560063600,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0011,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 78.2,
#   'apparentTemperature': 81.03,
#   'dewPoint': 75.78,
#   'humidity': 0.92,
#   'pressure': 1014.25,
#   'windSpeed': 8.1,
#   'windGust': 11.47,
#   'windBearing': 184,
#   'cloudCover': 0.12,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 295.68},
#  {'time': 1560067200,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0019,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 77.83,
#   'apparentTemperature': 79.71,
#   'dewPoint': 75.81,
#   'humidity': 0.94,
#   'pressure': 1014.11,
#   'windSpeed': 7.96,
#   'windGust': 11.64,
#   'windBearing': 184,
#   'cloudCover': 0.22,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 296.52},
#  {'time': 1560070800,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0037,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 77.91,
#   'apparentTemperature': 79.78,
#   'dewPoint': 75.76,
#   'humidity': 0.93,
#   'pressure': 1014.11,
#   'windSpeed': 8.46,
#   'windGust': 12.78,
#   'windBearing': 185,
#   'cloudCover': 0.22,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 297.32},
#  {'time': 1560074400,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0015,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 78.11,
#   'apparentTemperature': 79.96,
#   'dewPoint': 75.72,
#   'humidity': 0.92,
#   'pressure': 1014.15,
#   'windSpeed': 8.8,
#   'windGust': 13.16,
#   'windBearing': 187,
#   'cloudCover': 0.16,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 297.89},
#  {'time': 1560078000,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0014,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 78.71,
#   'apparentTemperature': 82.15,
#   'dewPoint': 75.11,
#   'humidity': 0.89,
#   'pressure': 1014.46,
#   'windSpeed': 9.65,
#   'windGust': 13.62,
#   'windBearing': 192,
#   'cloudCover': 0.2,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.42},
#  {'time': 1560081600,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0023,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 79.76,
#   'apparentTemperature': 84.34,
#   'dewPoint': 74.85,
#   'humidity': 0.85,
#   'pressure': 1014.82,
#   'windSpeed': 10.15,
#   'windGust': 14.03,
#   'windBearing': 191,
#   'cloudCover': 0.18,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 298.85},
#  {'time': 1560085200,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0052,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 82.02,
#   'apparentTemperature': 88.34,
#   'dewPoint': 74.46,
#   'humidity': 0.78,
#   'pressure': 1015.25,
#   'windSpeed': 10.15,
#   'windGust': 13.15,
#   'windBearing': 190,
#   'cloudCover': 0.14,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 299.25},
#  {'time': 1560088800,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0146,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 84.03,
#   'apparentTemperature': 91.17,
#   'dewPoint': 73.97,
#   'humidity': 0.72,
#   'pressure': 1015.73,
#   'windSpeed': 9.89,
#   'windGust': 11.51,
#   'windBearing': 186,
#   'cloudCover': 0.08,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 299.54},
#  {'time': 1560092400,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0242,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 85.6,
#   'apparentTemperature': 93.13,
#   'dewPoint': 73.62,
#   'humidity': 0.68,
#   'pressure': 1016.05,
#   'windSpeed': 9.81,
#   'windGust': 10.44,
#   'windBearing': 182,
#   'cloudCover': 0.07,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 299.75},
#  {'time': 1560096000,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0235,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 86.95,
#   'apparentTemperature': 94.89,
#   'dewPoint': 73.53,
#   'humidity': 0.65,
#   'pressure': 1016.19,
#   'windSpeed': 10.28,
#   'windGust': 10.67,
#   'windBearing': 178,
#   'cloudCover': 0.16,
#   'uvIndex': 9,
#   'visibility': 10,
#   'ozone': 299.69},
#  {'time': 1560099600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0221,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 89.43,
#   'apparentTemperature': 98.25,
#   'dewPoint': 73.59,
#   'humidity': 0.6,
#   'pressure': 1016.17,
#   'windSpeed': 10.93,
#   'windGust': 11.61,
#   'windBearing': 174,
#   'cloudCover': 0.29,
#   'uvIndex': 9,
#   'visibility': 10,
#   'ozone': 299.52},
#  {'time': 1560103200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0242,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 90.76,
#   'apparentTemperature': 100.16,
#   'dewPoint': 73.75,
#   'humidity': 0.58,
#   'pressure': 1016.07,
#   'windSpeed': 11.36,
#   'windGust': 12.56,
#   'windBearing': 170,
#   'cloudCover': 0.41,
#   'uvIndex': 9,
#   'visibility': 10,
#   'ozone': 299.08},
#  {'time': 1560106800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0267,
#   'precipProbability': 0.16,
#   'precipType': 'rain',
#   'temperature': 90.35,
#   'apparentTemperature': 99.75,
#   'dewPoint': 73.87,
#   'humidity': 0.59,
#   'pressure': 1015.86,
#   'windSpeed': 11.34,
#   'windGust': 13.4,
#   'windBearing': 165,
#   'cloudCover': 0.46,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 298.45},
#  {'time': 1560110400,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0354,
#   'precipProbability': 0.19,
#   'precipType': 'rain',
#   'temperature': 88.98,
#   'apparentTemperature': 98.13,
#   'dewPoint': 74.03,
#   'humidity': 0.62,
#   'pressure': 1015.56,
#   'windSpeed': 11.05,
#   'windGust': 14.22,
#   'windBearing': 161,
#   'cloudCover': 0.52,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 297.63},
#  {'time': 1560114000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0409,
#   'precipProbability': 0.21,
#   'precipType': 'rain',
#   'temperature': 87.45,
#   'apparentTemperature': 96.25,
#   'dewPoint': 74.2,
#   'humidity': 0.65,
#   'pressure': 1015.38,
#   'windSpeed': 10.59,
#   'windGust': 14.64,
#   'windBearing': 160,
#   'cloudCover': 0.57,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 297.13},
#  {'time': 1560117600,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0458,
#   'precipProbability': 0.25,
#   'precipType': 'rain',
#   'temperature': 86.04,
#   'apparentTemperature': 94.54,
#   'dewPoint': 74.46,
#   'humidity': 0.69,
#   'pressure': 1015.34,
#   'windSpeed': 9.97,
#   'windGust': 14.58,
#   'windBearing': 164,
#   'cloudCover': 0.6,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 297.27},
#  {'time': 1560121200,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.1055,
#   'precipProbability': 0.39,
#   'precipType': 'rain',
#   'temperature': 84.49,
#   'apparentTemperature': 92.51,
#   'dewPoint': 74.73,
#   'humidity': 0.73,
#   'pressure': 1015.42,
#   'windSpeed': 9.21,
#   'windGust': 14.2,
#   'windBearing': 172,
#   'cloudCover': 0.63,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 297.67},
#  {'time': 1560124800,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.1606,
#   'precipProbability': 0.43,
#   'precipType': 'rain',
#   'temperature': 83.42,
#   'apparentTemperature': 90.99,
#   'dewPoint': 74.93,
#   'humidity': 0.76,
#   'pressure': 1015.61,
#   'windSpeed': 8.47,
#   'windGust': 13.27,
#   'windBearing': 177,
#   'cloudCover': 0.65,
#   'uvIndex': 0,
#   'visibility': 9.6,
#   'ozone': 298.49},
#  {'time': 1560128400,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.1034,
#   'precipProbability': 0.34,
#   'precipType': 'rain',
#   'temperature': 82.83,
#   'apparentTemperature': 90.05,
#   'dewPoint': 74.96,
#   'humidity': 0.77,
#   'pressure': 1016.04,
#   'windSpeed': 7.62,
#   'windGust': 11.14,
#   'windBearing': 177,
#   'cloudCover': 0.67,
#   'uvIndex': 0,
#   'visibility': 9.23,
#   'ozone': 300.14},
#  {'time': 1560132000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0301,
#   'precipProbability': 0.18,
#   'precipType': 'rain',
#   'temperature': 82.68,
#   'apparentTemperature': 89.73,
#   'dewPoint': 74.88,
#   'humidity': 0.77,
#   'pressure': 1016.56,
#   'windSpeed': 6.72,
#   'windGust': 8.41,
#   'windBearing': 177,
#   'cloudCover': 0.68,
#   'uvIndex': 0,
#   'visibility': 9.09,
#   'ozone': 302.18},
#  {'time': 1560135600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0103,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 82.37,
#   'apparentTemperature': 89.19,
#   'dewPoint': 74.85,
#   'humidity': 0.78,
#   'pressure': 1016.9,
#   'windSpeed': 6.18,
#   'windGust': 6.63,
#   'windBearing': 178,
#   'cloudCover': 0.67,
#   'uvIndex': 0,
#   'visibility': 9.19,
#   'ozone': 303.1},
#  {'time': 1560139200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.006,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 81.73,
#   'apparentTemperature': 88.11,
#   'dewPoint': 74.88,
#   'humidity': 0.8,
#   'pressure': 1016.83,
#   'windSpeed': 6.38,
#   'windGust': 6.65,
#   'windBearing': 178,
#   'cloudCover': 0.63,
#   'uvIndex': 0,
#   'visibility': 9.49,
#   'ozone': 302.03},
#  {'time': 1560142800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0028,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 81.13,
#   'apparentTemperature': 87.07,
#   'dewPoint': 74.98,
#   'humidity': 0.82,
#   'pressure': 1016.56,
#   'windSpeed': 7.01,
#   'windGust': 7.49,
#   'windBearing': 177,
#   'cloudCover': 0.55,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.95},
#  {'time': 1560146400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0017,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 78.99,
#   'apparentTemperature': 82.79,
#   'dewPoint': 75.06,
#   'humidity': 0.88,
#   'pressure': 1016.28,
#   'windSpeed': 7.56,
#   'windGust': 8.39,
#   'windBearing': 176,
#   'cloudCover': 0.51,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.44},
#  {'time': 1560150000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0016,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 77.13,
#   'apparentTemperature': 78.95,
#   'dewPoint': 75.18,
#   'humidity': 0.94,
#   'pressure': 1015.97,
#   'windSpeed': 7.85,
#   'windGust': 9.44,
#   'windBearing': 175,
#   'cloudCover': 0.52,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.31},
#  {'time': 1560153600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0022,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 76.84,
#   'apparentTemperature': 78.7,
#   'dewPoint': 75.31,
#   'humidity': 0.95,
#   'pressure': 1015.66,
#   'windSpeed': 8.04,
#   'windGust': 10.62,
#   'windBearing': 172,
#   'cloudCover': 0.55,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.6},
#  {'time': 1560157200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0026,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 77.09,
#   'apparentTemperature': 78.93,
#   'dewPoint': 75.34,
#   'humidity': 0.94,
#   'pressure': 1015.59,
#   'windSpeed': 8.1,
#   'windGust': 11.32,
#   'windBearing': 172,
#   'cloudCover': 0.58,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.9},
#  {'time': 1560160800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0017,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 77.89,
#   'apparentTemperature': 79.69,
#   'dewPoint': 75.29,
#   'humidity': 0.92,
#   'pressure': 1015.86,
#   'windSpeed': 7.99,
#   'windGust': 11.12,
#   'windBearing': 173,
#   'cloudCover': 0.59,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.81},
#  {'time': 1560164400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0008,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 79,
#   'apparentTemperature': 82.82,
#   'dewPoint': 75.13,
#   'humidity': 0.88,
#   'pressure': 1016.34,
#   'windSpeed': 7.76,
#   'windGust': 10.43,
#   'windBearing': 175,
#   'cloudCover': 0.58,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 298.54},
#  {'time': 1560168000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0005,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 80.51,
#   'apparentTemperature': 85.84,
#   'dewPoint': 74.87,
#   'humidity': 0.83,
#   'pressure': 1016.85,
#   'windSpeed': 7.65,
#   'windGust': 9.87,
#   'windBearing': 177,
#   'cloudCover': 0.59,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 298.36},
#  {'time': 1560171600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.001,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 82.64,
#   'apparentTemperature': 89.36,
#   'dewPoint': 74.44,
#   'humidity': 0.76,
#   'pressure': 1017.39,
#   'windSpeed': 7.78,
#   'windGust': 9.69,
#   'windBearing': 179,
#   'cloudCover': 0.68,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 298.19},
#  {'time': 1560175200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0028,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 84.36,
#   'apparentTemperature': 91.62,
#   'dewPoint': 73.92,
#   'humidity': 0.71,
#   'pressure': 1017.96,
#   'windSpeed': 8.04,
#   'windGust': 9.65,
#   'windBearing': 182,
#   'cloudCover': 0.81,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 298.1},
#  {'time': 1560178800,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0047,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 85.5,
#   'apparentTemperature': 92.91,
#   'dewPoint': 73.52,
#   'humidity': 0.68,
#   'pressure': 1018.31,
#   'windSpeed': 8.4,
#   'windGust': 9.8,
#   'windBearing': 182,
#   'cloudCover': 0.88,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 297.82},
#  {'time': 1560182400,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0066,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 86.86,
#   'apparentTemperature': 94.61,
#   'dewPoint': 73.35,
#   'humidity': 0.64,
#   'pressure': 1018.33,
#   'windSpeed': 8.89,
#   'windGust': 10.03,
#   'windBearing': 179,
#   'cloudCover': 0.81,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 297.36},
#  {'time': 1560186000,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0114,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 89.51,
#   'apparentTemperature': 98.04,
#   'dewPoint': 73.3,
#   'humidity': 0.59,
#   'pressure': 1018.11,
#   'windSpeed': 9.46,
#   'windGust': 10.4,
#   'windBearing': 174,
#   'cloudCover': 0.7,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 296.64},
#  {'time': 1560189600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.015,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 90.85,
#   'apparentTemperature': 99.8,
#   'dewPoint': 73.32,
#   'humidity': 0.57,
#   'pressure': 1017.75,
#   'windSpeed': 9.82,
#   'windGust': 10.77,
#   'windBearing': 170,
#   'cloudCover': 0.61,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 296.04},
#  {'time': 1560193200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0129,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 90.46,
#   'apparentTemperature': 99.37,
#   'dewPoint': 73.39,
#   'humidity': 0.58,
#   'pressure': 1017.13,
#   'windSpeed': 9.88,
#   'windGust': 11.21,
#   'windBearing': 170,
#   'cloudCover': 0.61,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 295.47},
#  {'time': 1560196800,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0152,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 89.38,
#   'apparentTemperature': 98.07,
#   'dewPoint': 73.49,
#   'humidity': 0.6,
#   'pressure': 1016.35,
#   'windSpeed': 9.74,
#   'windGust': 11.66,
#   'windBearing': 172,
#   'cloudCover': 0.62,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 294.83},
#  {'time': 1560200400,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0195,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 88,
#   'apparentTemperature': 96.35,
#   'dewPoint': 73.58,
#   'humidity': 0.63,
#   'pressure': 1015.82,
#   'windSpeed': 9.48,
#   'windGust': 11.96,
#   'windBearing': 173,
#   'cloudCover': 0.63,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 294.25}]

# %%
for hour in Miami24:
    temp = hour['temperature']
    if hour['cloudCover'] > 0.5:
        print(temp,"and cloudy")
    else:
        print(temp)
# Out:
# 77.18 and cloudy
# 77.44 and cloudy
# 82.06 and cloudy
# 84.64 and cloudy
# 83.55
# 82.99 and cloudy
# 82.35 and cloudy
# 81.82
# 81.47
# 79.74
# 78.2
# 77.83
# 77.91
# 78.11
# 78.71
# 79.76
# 82.02
# 84.03
# 85.6
# 86.95
# 89.43
# 90.76
# 90.35
# 88.98 and cloudy
# 87.45 and cloudy
# 86.04 and cloudy
# 84.49 and cloudy
# 83.42 and cloudy
# 82.83 and cloudy
# 82.68 and cloudy
# 82.37 and cloudy
# 81.73 and cloudy
# 81.13 and cloudy
# 78.99 and cloudy
# 77.13 and cloudy
# 76.84 and cloudy
# 77.09 and cloudy
# 77.89 and cloudy
# 79 and cloudy
# 80.51 and cloudy
# 82.64 and cloudy
# 84.36 and cloudy
# 85.5 and cloudy
# 86.86 and cloudy
# 89.51 and cloudy
# 90.85 and cloudy
# 90.46 and cloudy
# 89.38 and cloudy
# 88 and cloudy

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
Above85 = []
MiamiTemp = []
for hour in Miami24:
    temp = hour['temperature']
    MiamiTemp.append(temp)
    if hour['temperature'] > 85:
        Above85.append(temp)
Percentage = f'{round(len(Above85)/len(MiamiTemp)*100,2)}%'
Percentage
# Out:
# '30.61%'

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1356393600')
CP_2012Christmas = response.json()
CP_2012Christmas['currently']['temperature']
# Out:
# 36.81

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1198540800')
CP_2007Christmas = response.json()
CP_2007Christmas['currently']['temperature']
# Out:
# 41.25

# %%
esponse = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1135468800')
CP_2005Christmas = response.json()
CP_2005Christmas['currently']['temperature']
# Out:
# 41.25
