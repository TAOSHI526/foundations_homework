# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
dark_sky_api_key = '50614b874393730eb3ea9d826fcd6278'
from dotenv import load_dotenv
load_dotenv()
import os

API_KEY = os.getenv("dark_sky_api_key")

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url = 'https://api.darksky.net/forecast/50614b874393730eb3ea9d826fcd6278/40.73,-74.08'

# %%
response = requests.get(url)
JC = response.json()

# %%
JC
# Out:
# {'latitude': 40.73,
#  'longitude': -74.08,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560002908,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 112,
#   'nearestStormBearing': 178,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 77.94,
#   'apparentTemperature': 77.94,
#   'dewPoint': 50.23,
#   'humidity': 0.38,
#   'pressure': 1020.49,
#   'windSpeed': 9.02,
#   'windGust': 9.19,
#   'windBearing': 61,
#   'cloudCover': 0.32,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 325.47},
#  'minutely': {'summary': 'Partly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560002880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560002940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560003960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560004980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560005940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560006480, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-night',
#   'data': [{'time': 1560002400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.62,
#     'apparentTemperature': 77.62,
#     'dewPoint': 50.35,
#     'humidity': 0.39,
#     'pressure': 1020.45,
#     'windSpeed': 8.94,
#     'windGust': 9.09,
#     'windBearing': 60,
#     'cloudCover': 0.33,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 325.34},
#    {'time': 1560006000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.92,
#     'apparentTemperature': 79.92,
#     'dewPoint': 49.39,
#     'humidity': 0.34,
#     'pressure': 1020.68,
#     'windSpeed': 9.61,
#     'windGust': 9.84,
#     'windBearing': 69,
#     'cloudCover': 0.3,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 326.22},
#    {'time': 1560009600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.59,
#     'apparentTemperature': 80.59,
#     'dewPoint': 50,
#     'humidity': 0.35,
#     'pressure': 1020.7,
#     'windSpeed': 10.62,
#     'windGust': 12.92,
#     'windBearing': 79,
#     'cloudCover': 0.49,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 326.95},
#    {'time': 1560013200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.32,
#     'apparentTemperature': 81.32,
#     'dewPoint': 50.28,
#     'humidity': 0.34,
#     'pressure': 1021.04,
#     'windSpeed': 10.79,
#     'windGust': 16.41,
#     'windBearing': 86,
#     'cloudCover': 0.76,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 327.69},
#    {'time': 1560016800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 82.31,
#     'apparentTemperature': 82.31,
#     'dewPoint': 49.68,
#     'humidity': 0.32,
#     'pressure': 1021.39,
#     'windSpeed': 10.55,
#     'windGust': 15.12,
#     'windBearing': 92,
#     'cloudCover': 0.73,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 328.58},
#    {'time': 1560020400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.74,
#     'apparentTemperature': 82.74,
#     'dewPoint': 49.84,
#     'humidity': 0.32,
#     'pressure': 1021.59,
#     'windSpeed': 10.2,
#     'windGust': 13.62,
#     'windBearing': 101,
#     'cloudCover': 0.64,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 330.02},
#    {'time': 1560024000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.72,
#     'apparentTemperature': 81.72,
#     'dewPoint': 50.36,
#     'humidity': 0.34,
#     'pressure': 1021.48,
#     'windSpeed': 10.75,
#     'windGust': 14.48,
#     'windBearing': 114,
#     'cloudCover': 0.48,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 331.71},
#    {'time': 1560027600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.66,
#     'apparentTemperature': 80.66,
#     'dewPoint': 49.51,
#     'humidity': 0.34,
#     'pressure': 1021.59,
#     'windSpeed': 10.63,
#     'windGust': 14.89,
#     'windBearing': 116,
#     'cloudCover': 0.5,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 333.03},
#    {'time': 1560031200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.62,
#     'apparentTemperature': 78.62,
#     'dewPoint': 48.92,
#     'humidity': 0.35,
#     'pressure': 1021.79,
#     'windSpeed': 10.2,
#     'windGust': 14.88,
#     'windBearing': 118,
#     'cloudCover': 0.41,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 333.63},
#    {'time': 1560034800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.44,
#     'apparentTemperature': 76.44,
#     'dewPoint': 48.47,
#     'humidity': 0.37,
#     'pressure': 1022.15,
#     'windSpeed': 9.51,
#     'windGust': 14.99,
#     'windBearing': 117,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.9},
#    {'time': 1560038400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.45,
#     'apparentTemperature': 73.45,
#     'dewPoint': 48.41,
#     'humidity': 0.41,
#     'pressure': 1022.75,
#     'windSpeed': 8.65,
#     'windGust': 16.42,
#     'windBearing': 117,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.98},
#    {'time': 1560042000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.76,
#     'apparentTemperature': 70.76,
#     'dewPoint': 48.84,
#     'humidity': 0.46,
#     'pressure': 1023.28,
#     'windSpeed': 7.71,
#     'windGust': 17.47,
#     'windBearing': 114,
#     'cloudCover': 0.5,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.91},
#    {'time': 1560045600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.37,
#     'apparentTemperature': 68.37,
#     'dewPoint': 49.87,
#     'humidity': 0.52,
#     'pressure': 1023.78,
#     'windSpeed': 6.64,
#     'windGust': 16.93,
#     'windBearing': 108,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.72},
#    {'time': 1560049200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.7,
#     'apparentTemperature': 66.7,
#     'dewPoint': 50.83,
#     'humidity': 0.57,
#     'pressure': 1024.25,
#     'windSpeed': 6.29,
#     'windGust': 15.89,
#     'windBearing': 97,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.57},
#    {'time': 1560052800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.5,
#     'apparentTemperature': 67.5,
#     'dewPoint': 50.01,
#     'humidity': 0.53,
#     'pressure': 1024.58,
#     'windSpeed': 6.54,
#     'windGust': 15.29,
#     'windBearing': 103,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.65},
#    {'time': 1560056400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.58,
#     'apparentTemperature': 66.58,
#     'dewPoint': 50.32,
#     'humidity': 0.56,
#     'pressure': 1024.53,
#     'windSpeed': 6.45,
#     'windGust': 15.15,
#     'windBearing': 94,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.8},
#    {'time': 1560060000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.71,
#     'apparentTemperature': 65.71,
#     'dewPoint': 50.52,
#     'humidity': 0.58,
#     'pressure': 1024.53,
#     'windSpeed': 6.43,
#     'windGust': 15.09,
#     'windBearing': 85,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.89},
#    {'time': 1560063600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.31,
#     'apparentTemperature': 64.31,
#     'dewPoint': 50.64,
#     'humidity': 0.61,
#     'pressure': 1024.75,
#     'windSpeed': 6.41,
#     'windGust': 15.15,
#     'windBearing': 78,
#     'cloudCover': 0.42,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.89},
#    {'time': 1560067200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.08,
#     'apparentTemperature': 63.08,
#     'dewPoint': 50.64,
#     'humidity': 0.64,
#     'pressure': 1025.04,
#     'windSpeed': 6.43,
#     'windGust': 15.28,
#     'windBearing': 72,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.79},
#    {'time': 1560070800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.35,
#     'apparentTemperature': 62.35,
#     'dewPoint': 50.52,
#     'humidity': 0.65,
#     'pressure': 1025.37,
#     'windSpeed': 6.62,
#     'windGust': 15.55,
#     'windBearing': 69,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.57},
#    {'time': 1560074400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.91,
#     'apparentTemperature': 62.91,
#     'dewPoint': 50.35,
#     'humidity': 0.64,
#     'pressure': 1025.7,
#     'windSpeed': 7,
#     'windGust': 16.03,
#     'windBearing': 69,
#     'cloudCover': 0.41,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.02},
#    {'time': 1560078000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.23,
#     'apparentTemperature': 64.23,
#     'dewPoint': 50.08,
#     'humidity': 0.6,
#     'pressure': 1026.08,
#     'windSpeed': 7.51,
#     'windGust': 16.59,
#     'windBearing': 71,
#     'cloudCover': 0.48,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.34},
#    {'time': 1560081600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.27,
#     'apparentTemperature': 66.27,
#     'dewPoint': 49.43,
#     'humidity': 0.55,
#     'pressure': 1026.39,
#     'windSpeed': 8.16,
#     'windGust': 17.11,
#     'windBearing': 75,
#     'cloudCover': 0.54,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 331.74},
#    {'time': 1560085200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.13,
#     'apparentTemperature': 69.13,
#     'dewPoint': 48.07,
#     'humidity': 0.47,
#     'pressure': 1026.68,
#     'windSpeed': 9.02,
#     'windGust': 17.53,
#     'windBearing': 84,
#     'cloudCover': 0.54,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 331.36},
#    {'time': 1560088800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.61,
#     'apparentTemperature': 72.61,
#     'dewPoint': 46.48,
#     'humidity': 0.39,
#     'pressure': 1026.94,
#     'windSpeed': 10.02,
#     'windGust': 17.95,
#     'windBearing': 96,
#     'cloudCover': 0.56,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 331.15},
#    {'time': 1560092400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 75.35,
#     'apparentTemperature': 75.35,
#     'dewPoint': 45.43,
#     'humidity': 0.35,
#     'pressure': 1027.08,
#     'windSpeed': 10.91,
#     'windGust': 18.29,
#     'windBearing': 106,
#     'cloudCover': 0.59,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 330.87},
#    {'time': 1560096000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.88,
#     'apparentTemperature': 76.88,
#     'dewPoint': 45.29,
#     'humidity': 0.33,
#     'pressure': 1027.09,
#     'windSpeed': 11.73,
#     'windGust': 18.44,
#     'windBearing': 112,
#     'cloudCover': 0.55,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 330.47},
#    {'time': 1560099600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.62,
#     'apparentTemperature': 77.62,
#     'dewPoint': 45.58,
#     'humidity': 0.32,
#     'pressure': 1026.98,
#     'windSpeed': 12.44,
#     'windGust': 18.45,
#     'windBearing': 115,
#     'cloudCover': 0.5,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 330.09},
#    {'time': 1560103200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.92,
#     'apparentTemperature': 77.92,
#     'dewPoint': 45.68,
#     'humidity': 0.32,
#     'pressure': 1026.83,
#     'windSpeed': 12.82,
#     'windGust': 18.43,
#     'windBearing': 117,
#     'cloudCover': 0.51,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 329.87},
#    {'time': 1560106800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.33,
#     'apparentTemperature': 77.33,
#     'dewPoint': 45.37,
#     'humidity': 0.32,
#     'pressure': 1026.58,
#     'windSpeed': 12.7,
#     'windGust': 18.38,
#     'windBearing': 119,
#     'cloudCover': 0.65,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 330.02},
#    {'time': 1560110400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.15,
#     'apparentTemperature': 76.15,
#     'dewPoint': 44.95,
#     'humidity': 0.33,
#     'pressure': 1026.28,
#     'windSpeed': 12.23,
#     'windGust': 18.25,
#     'windBearing': 120,
#     'cloudCover': 0.85,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 330.38},
#    {'time': 1560114000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.88,
#     'apparentTemperature': 74.88,
#     'dewPoint': 44.65,
#     'humidity': 0.34,
#     'pressure': 1026.04,
#     'windSpeed': 11.66,
#     'windGust': 18.04,
#     'windBearing': 119,
#     'cloudCover': 0.95,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 330.57},
#    {'time': 1560117600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.59,
#     'apparentTemperature': 73.59,
#     'dewPoint': 44.56,
#     'humidity': 0.35,
#     'pressure': 1025.95,
#     'windSpeed': 11.04,
#     'windGust': 17.72,
#     'windBearing': 118,
#     'cloudCover': 0.85,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 330.49},
#    {'time': 1560121200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.14,
#     'apparentTemperature': 72.14,
#     'dewPoint': 44.57,
#     'humidity': 0.37,
#     'pressure': 1025.9,
#     'windSpeed': 10.33,
#     'windGust': 17.29,
#     'windBearing': 115,
#     'cloudCover': 0.67,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.2},
#    {'time': 1560124800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.65,
#     'apparentTemperature': 70.65,
#     'dewPoint': 44.94,
#     'humidity': 0.4,
#     'pressure': 1025.89,
#     'windSpeed': 9.71,
#     'windGust': 16.92,
#     'windBearing': 111,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.87},
#    {'time': 1560128400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.04,
#     'apparentTemperature': 69.04,
#     'dewPoint': 45.8,
#     'humidity': 0.43,
#     'pressure': 1025.98,
#     'windSpeed': 9.21,
#     'windGust': 16.69,
#     'windBearing': 107,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.44},
#    {'time': 1560132000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.3,
#     'apparentTemperature': 67.3,
#     'dewPoint': 47.01,
#     'humidity': 0.48,
#     'pressure': 1026.11,
#     'windSpeed': 8.8,
#     'windGust': 16.59,
#     'windBearing': 102,
#     'cloudCover': 0.71,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.04},
#    {'time': 1560135600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.92,
#     'apparentTemperature': 65.92,
#     'dewPoint': 48.18,
#     'humidity': 0.53,
#     'pressure': 1026.05,
#     'windSpeed': 8.47,
#     'windGust': 16.64,
#     'windBearing': 99,
#     'cloudCover': 0.79,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.71},
#    {'time': 1560139200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.94,
#     'apparentTemperature': 64.94,
#     'dewPoint': 49.23,
#     'humidity': 0.57,
#     'pressure': 1025.71,
#     'windSpeed': 8.16,
#     'windGust': 16.81,
#     'windBearing': 96,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.56},
#    {'time': 1560142800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.25,
#     'apparentTemperature': 64.25,
#     'dewPoint': 50.24,
#     'humidity': 0.6,
#     'pressure': 1025.22,
#     'windSpeed': 7.92,
#     'windGust': 17.09,
#     'windBearing': 94,
#     'cloudCover': 0.72,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.53},
#    {'time': 1560146400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 63.52,
#     'apparentTemperature': 63.52,
#     'dewPoint': 51.28,
#     'humidity': 0.64,
#     'pressure': 1024.64,
#     'windSpeed': 7.8,
#     'windGust': 17.41,
#     'windBearing': 93,
#     'cloudCover': 0.71,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.3},
#    {'time': 1560150000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 63,
#     'apparentTemperature': 63,
#     'dewPoint': 52.27,
#     'humidity': 0.68,
#     'pressure': 1023.94,
#     'windSpeed': 7.83,
#     'windGust': 17.66,
#     'windBearing': 90,
#     'cloudCover': 0.78,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.86},
#    {'time': 1560153600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 62.66,
#     'apparentTemperature': 62.66,
#     'dewPoint': 53.26,
#     'humidity': 0.71,
#     'pressure': 1023.12,
#     'windSpeed': 7.99,
#     'windGust': 17.94,
#     'windBearing': 88,
#     'cloudCover': 0.89,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.23},
#    {'time': 1560157200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0018,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 62.44,
#     'apparentTemperature': 62.44,
#     'dewPoint': 54.24,
#     'humidity': 0.75,
#     'pressure': 1022.49,
#     'windSpeed': 8.2,
#     'windGust': 18.38,
#     'windBearing': 86,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 326.48},
#    {'time': 1560160800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0027,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 62.69,
#     'apparentTemperature': 62.69,
#     'dewPoint': 55.19,
#     'humidity': 0.77,
#     'pressure': 1022.14,
#     'windSpeed': 8.45,
#     'windGust': 19.08,
#     'windBearing': 85,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 325.61},
#    {'time': 1560164400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0044,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 63.04,
#     'apparentTemperature': 63.04,
#     'dewPoint': 56.13,
#     'humidity': 0.78,
#     'pressure': 1021.93,
#     'windSpeed': 8.76,
#     'windGust': 19.98,
#     'windBearing': 86,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.68},
#    {'time': 1560168000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0089,
#     'precipProbability': 0.23,
#     'precipType': 'rain',
#     'temperature': 63.41,
#     'apparentTemperature': 63.41,
#     'dewPoint': 57.21,
#     'humidity': 0.8,
#     'pressure': 1021.64,
#     'windSpeed': 9.12,
#     'windGust': 20.92,
#     'windBearing': 88,
#     'cloudCover': 0.98,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 323.86},
#    {'time': 1560171600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0269,
#     'precipProbability': 0.43,
#     'precipType': 'rain',
#     'temperature': 64.19,
#     'apparentTemperature': 64.19,
#     'dewPoint': 58.54,
#     'humidity': 0.82,
#     'pressure': 1021.15,
#     'windSpeed': 9.57,
#     'windGust': 22.21,
#     'windBearing': 93,
#     'cloudCover': 0.98,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 323.02},
#    {'time': 1560175200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0665,
#     'precipProbability': 0.58,
#     'precipType': 'rain',
#     'temperature': 65.12,
#     'apparentTemperature': 65.26,
#     'dewPoint': 60.01,
#     'humidity': 0.84,
#     'pressure': 1020.57,
#     'windSpeed': 10.08,
#     'windGust': 23.52,
#     'windBearing': 101,
#     'cloudCover': 0.99,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 322.32}]},
#  'daily': {'summary': 'Rain on Monday through Thursday, with high temperatures bottoming out at 73°F on Monday.',
#   'icon': 'rain',
#   'data': [{'time': 1559966400,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1559985995,
#     'sunsetTime': 1560040027,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.001,
#     'precipIntensityMaxTime': 1560016800,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 82.74,
#     'temperatureHighTime': 1560020400,
#     'temperatureLow': 62.35,
#     'temperatureLowTime': 1560070800,
#     'apparentTemperatureHigh': 82.74,
#     'apparentTemperatureHighTime': 1560020400,
#     'apparentTemperatureLow': 62.35,
#     'apparentTemperatureLowTime': 1560070800,
#     'dewPoint': 53.49,
#     'humidity': 0.56,
#     'pressure': 1020.08,
#     'windSpeed': 5.55,
#     'windGust': 17.47,
#     'windGustTime': 1560042000,
#     'windBearing': 94,
#     'cloudCover': 0.36,
#     'uvIndex': 7,
#     'uvIndexTime': 1560009600,
#     'visibility': 9.61,
#     'ozone': 328.09,
#     'temperatureMin': 62.95,
#     'temperatureMinTime': 1559977200,
#     'temperatureMax': 82.74,
#     'temperatureMaxTime': 1560020400,
#     'apparentTemperatureMin': 63.24,
#     'apparentTemperatureMinTime': 1559977200,
#     'apparentTemperatureMax': 82.74,
#     'apparentTemperatureMaxTime': 1560020400},
#    {'time': 1560052800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560072383,
#     'sunsetTime': 1560126461,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560092400,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperatureHigh': 77.92,
#     'temperatureHighTime': 1560103200,
#     'temperatureLow': 62.44,
#     'temperatureLowTime': 1560157200,
#     'apparentTemperatureHigh': 77.92,
#     'apparentTemperatureHighTime': 1560103200,
#     'apparentTemperatureLow': 62.44,
#     'apparentTemperatureLowTime': 1560157200,
#     'dewPoint': 47.46,
#     'humidity': 0.46,
#     'pressure': 1025.97,
#     'windSpeed': 8.87,
#     'windGust': 18.45,
#     'windGustTime': 1560099600,
#     'windBearing': 102,
#     'cloudCover': 0.58,
#     'uvIndex': 7,
#     'uvIndexTime': 1560099600,
#     'visibility': 10,
#     'ozone': 331.34,
#     'temperatureMin': 62.35,
#     'temperatureMinTime': 1560070800,
#     'temperatureMax': 77.92,
#     'temperatureMaxTime': 1560103200,
#     'apparentTemperatureMin': 62.35,
#     'apparentTemperatureMinTime': 1560070800,
#     'apparentTemperatureMax': 77.92,
#     'apparentTemperatureMaxTime': 1560103200},
#    {'time': 1560139200,
#     'summary': 'Rain until afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560158773,
#     'sunsetTime': 1560212894,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0204,
#     'precipIntensityMax': 0.0979,
#     'precipIntensityMaxTime': 1560178800,
#     'precipProbability': 0.98,
#     'precipType': 'rain',
#     'temperatureHigh': 72.77,
#     'temperatureHighTime': 1560204000,
#     'temperatureLow': 68.01,
#     'temperatureLowTime': 1560254400,
#     'apparentTemperatureHigh': 73.56,
#     'apparentTemperatureHighTime': 1560204000,
#     'apparentTemperatureLow': 68.7,
#     'apparentTemperatureLowTime': 1560254400,
#     'dewPoint': 60.35,
#     'humidity': 0.8,
#     'pressure': 1019.28,
#     'windSpeed': 8.59,
#     'windGust': 23.97,
#     'windGustTime': 1560178800,
#     'windBearing': 117,
#     'cloudCover': 0.95,
#     'uvIndex': 4,
#     'uvIndexTime': 1560178800,
#     'visibility': 10,
#     'ozone': 324.35,
#     'temperatureMin': 62.44,
#     'temperatureMinTime': 1560157200,
#     'temperatureMax': 72.77,
#     'temperatureMaxTime': 1560204000,
#     'apparentTemperatureMin': 62.44,
#     'apparentTemperatureMinTime': 1560157200,
#     'apparentTemperatureMax': 73.56,
#     'apparentTemperatureMaxTime': 1560204000},
#    {'time': 1560225600,
#     'summary': 'Rain in the morning.',
#     'icon': 'rain',
#     'sunriseTime': 1560245166,
#     'sunsetTime': 1560299324,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0136,
#     'precipIntensityMax': 0.0717,
#     'precipIntensityMaxTime': 1560243600,
#     'precipProbability': 0.89,
#     'precipType': 'rain',
#     'temperatureHigh': 78.64,
#     'temperatureHighTime': 1560279600,
#     'temperatureLow': 61.71,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 78.64,
#     'apparentTemperatureHighTime': 1560279600,
#     'apparentTemperatureLow': 61.71,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 56.98,
#     'humidity': 0.62,
#     'pressure': 1012.53,
#     'windSpeed': 5.65,
#     'windGust': 26.27,
#     'windGustTime': 1560254400,
#     'windBearing': 297,
#     'cloudCover': 0.6,
#     'uvIndex': 7,
#     'uvIndexTime': 1560276000,
#     'visibility': 9.25,
#     'ozone': 329.02,
#     'temperatureMin': 68.01,
#     'temperatureMinTime': 1560254400,
#     'temperatureMax': 78.64,
#     'temperatureMaxTime': 1560279600,
#     'apparentTemperatureMin': 68.7,
#     'apparentTemperatureMinTime': 1560254400,
#     'apparentTemperatureMax': 78.64,
#     'apparentTemperatureMaxTime': 1560279600},
#    {'time': 1560312000,
#     'summary': 'Rain overnight.',
#     'icon': 'rain',
#     'sunriseTime': 1560331560,
#     'sunsetTime': 1560385753,
#     'moonPhase': 0.34,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 79.61,
#     'temperatureHighTime': 1560362400,
#     'temperatureLow': 63.81,
#     'temperatureLowTime': 1560423600,
#     'apparentTemperatureHigh': 79.61,
#     'apparentTemperatureHighTime': 1560362400,
#     'apparentTemperatureLow': 63.91,
#     'apparentTemperatureLowTime': 1560423600,
#     'dewPoint': 43.6,
#     'humidity': 0.39,
#     'pressure': 1021.64,
#     'windSpeed': 1.22,
#     'windGust': 18.29,
#     'windGustTime': 1560312000,
#     'windBearing': 111,
#     'cloudCover': 0.58,
#     'uvIndex': 8,
#     'uvIndexTime': 1560355200,
#     'visibility': 10,
#     'ozone': 331.81,
#     'temperatureMin': 61.71,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 79.61,
#     'temperatureMaxTime': 1560362400,
#     'apparentTemperatureMin': 61.71,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 79.61,
#     'apparentTemperatureMaxTime': 1560362400},
#    {'time': 1560398400,
#     'summary': 'Rain until afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560417956,
#     'sunsetTime': 1560472181,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0409,
#     'precipIntensityMax': 0.1014,
#     'precipIntensityMaxTime': 1560448800,
#     'precipProbability': 0.99,
#     'precipType': 'rain',
#     'temperatureHigh': 78.64,
#     'temperatureHighTime': 1560456000,
#     'temperatureLow': 64.07,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 79.43,
#     'apparentTemperatureHighTime': 1560456000,
#     'apparentTemperatureLow': 64.07,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 62.49,
#     'humidity': 0.76,
#     'pressure': 1010.72,
#     'windSpeed': 7.58,
#     'windGust': 26.73,
#     'windGustTime': 1560481200,
#     'windBearing': 153,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'uvIndexTime': 1560438000,
#     'visibility': 8.57,
#     'ozone': 323.53,
#     'temperatureMin': 63.81,
#     'temperatureMinTime': 1560423600,
#     'temperatureMax': 78.64,
#     'temperatureMaxTime': 1560456000,
#     'apparentTemperatureMin': 63.91,
#     'apparentTemperatureMinTime': 1560423600,
#     'apparentTemperatureMax': 79.43,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560484800,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1560504354,
#     'sunsetTime': 1560558606,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0006,
#     'precipIntensityMax': 0.0088,
#     'precipIntensityMaxTime': 1560484800,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperatureHigh': 77.35,
#     'temperatureHighTime': 1560546000,
#     'temperatureLow': 64.57,
#     'temperatureLowTime': 1560589200,
#     'apparentTemperatureHigh': 77.35,
#     'apparentTemperatureHighTime': 1560546000,
#     'apparentTemperatureLow': 64.57,
#     'apparentTemperatureLowTime': 1560589200,
#     'dewPoint': 50.98,
#     'humidity': 0.51,
#     'pressure': 1012.81,
#     'windSpeed': 9.04,
#     'windGust': 26.77,
#     'windGustTime': 1560484800,
#     'windBearing': 258,
#     'cloudCover': 0.12,
#     'uvIndex': 8,
#     'uvIndexTime': 1560528000,
#     'visibility': 9.89,
#     'ozone': 354.84,
#     'temperatureMin': 64.07,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 77.35,
#     'temperatureMaxTime': 1560546000,
#     'apparentTemperatureMin': 64.07,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 77.35,
#     'apparentTemperatureMaxTime': 1560546000},
#    {'time': 1560571200,
#     'summary': 'Mostly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560590754,
#     'sunsetTime': 1560645031,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1560643200,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 83.37,
#     'temperatureHighTime': 1560628800,
#     'temperatureLow': 67.09,
#     'temperatureLowTime': 1560675600,
#     'apparentTemperatureHigh': 83.37,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 67.09,
#     'apparentTemperatureLowTime': 1560675600,
#     'dewPoint': 51.04,
#     'humidity': 0.45,
#     'pressure': 1018.43,
#     'windSpeed': 8.55,
#     'windGust': 27.43,
#     'windGustTime': 1560625200,
#     'windBearing': 257,
#     'cloudCover': 0.29,
#     'uvIndex': 8,
#     'uvIndexTime': 1560614400,
#     'visibility': 10,
#     'ozone': 351.79,
#     'temperatureMin': 64.57,
#     'temperatureMinTime': 1560589200,
#     'temperatureMax': 83.37,
#     'temperatureMaxTime': 1560628800,
#     'apparentTemperatureMin': 64.57,
#     'apparentTemperatureMinTime': 1560589200,
#     'apparentTemperatureMax': 83.37,
#     'apparentTemperatureMaxTime': 1560628800}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.036,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
JC_current = JC['currently']

# %%
JC_current['windSpeed']
# Out:
# 9.02

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
